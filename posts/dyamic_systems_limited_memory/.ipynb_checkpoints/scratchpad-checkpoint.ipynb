# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import numpy as np
import wave
import sys
import pandas as pd

# This is needed to compensate for matplotlib notebook's tendancy to blow up images when plotted inline
# %matplotlib notebook
from matplotlib import rcParams
rcParams['figure.autolayout'] = True

# %load_ext autoreload
# %autoreload 2

# %%
# short function to plot wav audio file - raw signal
def plot_audio_signal(filename):
    f, (ax) = plt.subplots(1, 1, sharey=True,figsize=(10, 4))

    # load in audio file
    spf = wave.open(filename,'r')

    # extract audio from wav file
    sig = spf.readframes(-1)
    sig = np.fromstring(sig, 'Int16')
    fs = spf.getframerate()
    Time=np.linspace(0, len(sig)/fs, num=len(sig))

    # set up figure and plot
    ax.plot(Time,sig,color = 'r')
    ax.set_yticks([],[])
    ax.axis('off')  
    return Time,sig

# %%
t,s = plot_audio_signal('dog2.wav')
# Out:
# /Users/Nurgetson/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:10: DeprecationWarning: Numeric-style type codes are deprecated and will result in an error in the future.
#   # Remove the CWD from sys.path while we load stuff.
# /Users/Nurgetson/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:10: DeprecationWarning: The binary mode of fromstring is deprecated, as it behaves surprisingly on unicode inputs. Use frombuffer instead
#   # Remove the CWD from sys.path while we load stuff.
# /Users/Nurgetson/anaconda3/lib/python3.7/site-packages/matplotlib/figure.py:2299: UserWarning: This figure includes Axes that are not compatible with tight_layout, so results might be incorrect.
#   warnings.warn("This figure includes Axes that are not compatible "

# %%
fig = plt.figure()
plt.plot(s[20000:])
# Out:
# /Users/Nurgetson/anaconda3/lib/python3.7/site-packages/matplotlib/figure.py:2299: UserWarning: This figure includes Axes that are not compatible with tight_layout, so results might be incorrect.
#   warnings.warn("This figure includes Axes that are not compatible "

# %%
np.savetxt('dog_audio.csv',s[20000:],delimiter=',')

# %%
x = np.loadtxt('dog_audio.csv',delimiter=',')

# %%
# short function to plot wav audio file - raw signal
def plot_audio_signal(sig):
    f, (ax1,ax2) = plt.subplots(2,1,figsize=(12, 9))

    # load in audio file
#     spf = wave.open(filename,'r')

    # extract audio from wav file
#     sig = spf.readframes(-1)
#     sig = np.fromstring(sig, 'Int16')
#     fs = spf.getframerate()
#     Time=np.linspace(0, len(sig)/fs, num=len(sig))

#     # set up figure and plot
#     ax1.plot(Time,sig,color = 'r')
    ax1.plot(sig,color='r')
    ax1.set_yticks([],[])
    ax1.axis('off')  
   
    # plot spectrogram
    ax2.specgram(sig, NFFT=128,Fs=0.1,noverlap=0,cmap='jet')
    
    ax2.set_yticks([],[])
    ax2.axis('off')

# %%
x_mean = np.mean(x)
x_std = np.std(x)
x = (x - x_mean)/x_std

# %%
plot_audio_signal(x[:10000])
# Out:
# /Users/Nurgetson/anaconda3/lib/python3.7/site-packages/matplotlib/figure.py:2299: UserWarning: This figure includes Axes that are not compatible with tight_layout, so results might be incorrect.
#   warnings.warn("This figure includes Axes that are not compatible "

# %%
plot_audio_signal('dog2.wav')
# Out:
# /Users/Nurgetson/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:11: DeprecationWarning: Numeric-style type codes are deprecated and will result in an error in the future.
#   # This is added back by InteractiveShellApp.init_path()
# /Users/Nurgetson/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:11: DeprecationWarning: The binary mode of fromstring is deprecated, as it behaves surprisingly on unicode inputs. Use frombuffer instead
#   # This is added back by InteractiveShellApp.init_path()
# /Users/Nurgetson/anaconda3/lib/python3.7/site-packages/matplotlib/axes/_axes.py:7674: RuntimeWarning: divide by zero encountered in log10
#   Z = 10. * np.log10(spec)
# /Users/Nurgetson/anaconda3/lib/python3.7/site-packages/matplotlib/figure.py:2299: UserWarning: This figure includes Axes that are not compatible with tight_layout, so results might be incorrect.
#   warnings.warn("This figure includes Axes that are not compatible "
