# %% [markdown]
# # Fitted Q-learning algo

# %% [markdown]
# Below is a version of the fitted Q-Learning algorithm described [last time]((https://www.dropbox.com/s/3qjqhpo1mix0w9h/deep_QLearning_part_2_SLIDES.pdf?dl=0).  Recall the main variation here is just this: instead of updating $Q$ *inside* each episode, we wait (at least) until the end of the episode to update.
#
# A few quirks of this implementation:
# - its written in Keras-Tensorflow
# - The size of memory for memory replay is fixed at a number of episodes instead of a number of steps.
# - There are a large number of user-controls - defined in the initialization - that allow for a wide range of use, including parameters to control how often the weights of $Q$ are saved, how often $Q$ is updated (in terms of number of episodes),...

# %%
import numpy as np
import copy
import os
import pickle
from keras.layers import Dense
from keras.optimizers import RMSprop
from keras.models import Sequential
import gym

class QLearner():
    # load in simulator, initialize global variables
    def __init__(self,gymname,dirname,savename,**kwargs):
        # load in gym simulator
        self.simulator = gym.make(gymname) 
             
        # Q learn basic params
        self.explore_val = 1       # how often should an action be chosen randomly vs using the optimal control law, larger values mean actions are more often chosen randomly
        self.explore_decay = 0.99  # after each episode the explore_val is multiplied by explore_decay to (potentially) shrink it
        self.gamma = 1             # short-term/long-term trade-off param
        self.num_episodes = 500    # number of episodes of simulation to perform
        self.save_weight_freq = 10 # controls how often (in number of episodes) the weights of $Q$ are saved 
        self.memory = []           # memory container
        
        # fitted Q-Learning params
        self.episode_update = 1     # after how many episodes should we update Q?
        self.memory_length = 10     # length of memory replay (in episodes)

        # simulation-specific params
        self.exit_level = 200       # sets the optimal episode reward required for 'success'
        self.exit_window = 100      # sets the window over which average total reward per episode must be >= exit_level  to deem Q resolved successfully
        
        # let user define each of the params above
        if "gamma" in kwargs:   
            self.gamma = args['gamma']
        if 'explore_val' in kwargs:
            self.explore_val = kwargs['explore_val']
        if 'explore_decay' in kwargs:
            self.explore_decay = kwargs['explore_decay']
        if 'num_episodes' in kwargs:
            self.num_episodes = kwargs['num_episodes']
        if 'episode_update' in kwargs:
            self.episode_update = kwargs['episode_update']
        if 'exit_level' in kwargs:
            self.exit_level = kwargs['exit_level']
        if 'exit_window' in kwargs:
            self.exit_window = kwargs['exit_window']  
        if 'save_weight_freq' in kwargs:
            self.save_weight_freq = kwargs['save_weight_freq']
        if 'memory_length' in kwargs:
            self.memory_length = kwargs['memory_length']
        if 'episode_update' in kwargs:
            self.episode_update = kwargs['episode_update']
            
        # get simulation-specific variables from simulator
        self.num_actions = self.simulator.action_space.n
        state = self.simulator.reset()    
        self.state_dim = np.size(state)
        self.training_reward = []
        
        ### initialize logs ###
        # create text file for training log
        self.logname = dirname + '/training_logs/' + savename + '.txt'
        self.reward_logname = dirname + '/reward_logs/' + savename + '.txt'
        self.weight_name = dirname + '/saved_model_weights/' + savename + '.pkl' 
        self.model_name = dirname + '/models/' + savename + '.json'

        self.init_log(self.logname)
        self.init_log(self.reward_logname)
        self.init_log(self.weight_name)
        self.init_log(self.model_name)
     
    ##### logging functions #####
    def init_log(self,logname):
        # delete log if old version exists
        if os.path.exists(logname): 
            os.remove(logname)
            
    def update_log(self,logname,update):
        if type(update) == str:
            logfile = open(logname, "a")
            logfile.write(update)
            logfile.close() 
        else:
            weights = []
            if os.path.exists(logname):
                with open(logname,'rb') as rfp: 
                    weights = pickle.load(rfp)
            weights.append(update)

            with open(logname,'wb') as wfp:
                pickle.dump(weights, wfp)
    
    ##### functions for creating / updating Q #####
    def initialize_Q(self,**kwargs):
        # default parameters for network
        layer_sizes = [10,10]      # two hidden layers, 10 units each, by default
        activation = 'relu'
        if 'layer_sizes' in kwargs:
            layer_sizes = kwargs['layer_sizes']
        if 'activation' in kwargs:
            activation = kwargs['activation']

        # default parameters for optimizer - reset by hand
        loss = 'mse'
        lr = 10**(-2)
        if 'alpha' in kwargs:
            lr = kwargs['alpha']
        optimizer = RMSprop(lr = lr)        

        # input / output sizes of network
        input_dim = self.state_dim
        output_dim = self.num_actions

        # build model based on parameters
        self.model = Sequential()

        # add input layer
        self.model.add(Dense(layer_sizes[0], input_dim=input_dim, activation=activation))

        # add hidden layers
        for U in layer_sizes[1:]:
            self.model.add(Dense(U,activation=activation))

        # add output layer
        self.model.add(Dense(output_dim, activation='linear'))

        # chose optimizer and its associated parameters
        self.model.compile(loss=loss, optimizer=optimizer)
        
        # initialize Q
        self.Q = self.model.predict
        
        # since its easy to save models with keras / tensorflow, save to file
        model_json = self.model.to_json()
        with open(self.model_name, "w") as json_file:
            json_file.write(model_json)

    # update Q function
    def update_Q(self):        
        # generate q_values based on most recent Q
        q_vals = []
        states = []
        for i in range(len(self.memory)):    
            # get episode_data
            episode_data = self.memory[i]
            
            # loop over episode data and create input/output pairs
            for j in range(len(episode_data)):
                # get next sample of episode
                sample = episode_data[j]
            
                # strip sample for parts
                state = sample[0]
                next_state = sample[1]
                action = sample[2]
                reward = sample[3]
                done = sample[4]

                ### for cartpole only - check if done, and alter reward to improve learning ###
                done,reward = self.check_done(done,reward)

                # compute and store q value
                q = reward 
                if done == False:
                    qs = self.Q(next_state)
                    q += self.gamma*np.max(qs)

                # clamp all other models to their current values for this input/output pair
                q_update = self.Q(state).flatten()
                q_update[action] = q
                q_vals.append(q_update)
                states.append(state.T)
            
        # convert lists to numpy arrays for regressor
        s_in = np.array(states).T
        q_vals = np.array(q_vals).T
        s_in = s_in[0,:,:]
                            
        # take descent step
        num_pts = s_in.shape[1]
        self.model.fit(x=s_in.T,y=q_vals.T,batch_size=num_pts, epochs=1,verbose = 0)
        
        # update Q based on regressor updates
        self.Q = self.model.predict
        
    ##### functions for adjusting replay memory #####
    # update memory - add sample to list, remove oldest samples 
    def update_memory(self,episode_data):
        # add most recent trial data to memory
        self.memory.append(episode_data)

        # clip memory if it gets too long    
        num_episodes = len(self.memory)
        if num_episodes >= self.memory_length:    
            num_delete = num_episodes - self.memory_length
            self.memory[:num_delete] = []
    
    ##### Q Learning functionality #####
    # special function to check done
    def check_done(self,done,reward):
        if done == True:
            reward = -100
        return done,reward
    
    # state normalizer
    def state_normalizer(self,states):
        states = np.array(states)[np.newaxis,:]
        return states
    
    # choose next action
    def choose_action(self,state):
        # pick action at random
        p = np.random.rand(1)   
        action = np.random.randint(self.num_actions)
            
        # pick action based on exploiting
        qs = self.Q(state) 
        if p > self.explore_val:
            action = np.argmax(qs)
        return action
    
    # main training function
    def train(self,**kwargs):             
       
        ### start main Q-learning loop ###
        for n in range(self.num_episodes): 
            # pick this episode's starting position - randomly initialize from f_system
            state = self.simulator.reset()    
            state = self.state_normalizer(state)
            total_episode_reward = 0
            done = False
            
            # get out exploit parameter for this episode
            if self.explore_val > 0.01:
                self.explore_val *= self.explore_decay
                    
            # run episode
            step = 0
            episode_data = []
            while done == False and step < 500:    
                # choose next action
                action = self.choose_action(state)
    
                # transition to next state, get associated reward
                next_state,reward,done,info = self.simulator.step(action)  
                next_state = self.state_normalizer(next_state)
                
                # store data for transition after episode ends
                episode_data.append([state,next_state,action,reward,done])

                # update total reward from this episode
                total_episode_reward+=reward
                state = copy.deepcopy(next_state)
                step+=1
            
            # update memory with this episode's data
            self.update_memory(episode_data)
            
            # update Q function
            if np.mod(n,self.episode_update) == 0:
                self.update_Q()  
                  
            # update episode reward greater than exit_level, add to counter
            exit_ave = total_episode_reward
            if n >= self.exit_window:
                exit_ave = np.sum(np.array(self.training_reward[-self.exit_window:]))/self.exit_window

            ### print out updates ###
            update = 'episode ' + str(n+1) +  ' of ' + str(self.num_episodes) + ' complete, ' +  ' explore val = ' + str(np.round(self.explore_val,3)) + ', episode reward = ' + str(np.round(total_episode_reward,1)) + ', ave reward = ' + str(np.round(exit_ave,1))
                              
            print (update)
            self.update_log(self.logname,update + '\n')
                              
            update = str(total_episode_reward) + '\n'
            self.update_log(self.reward_logname,update)

            ### store this episode's computation time and training reward history
            self.training_reward.append(total_episode_reward)

            # save latest weights from this episode 
            if np.mod(n,self.save_weight_freq) == 0:
                update = self.model.get_weights()
                self.update_log(self.weight_name,update)
            
            # if the total episode reward is greater than exit level for 10 consecutive episodes, break
            if exit_ave >= self.exit_level and n >= self.exit_window:
                break
            
        ### save weights ###
        update = 'q-learning algorithm complete'
        self.update_log(self.logname,update + '\n')
        print (update)

# %% [markdown]
# # Episode reward history plotter

# %%
import matplotlib.pyplot as plt
import numpy as np

# moving average function
def moving_average(x,D):
    y = []
    for p in range(len(x)+1):
        # make next element
        b = np.sum(x[np.maximum(0,p-D):p])/float(D)
        y.append(b)
    return np.array(y)

def plot_reward_history(logname,**kwargs):
    start = 1
    window_length = 5
    if 'window_length' in kwargs:
        window_length = kwargs['window_length']
    if 'start' in kwargs:
        start = kwargs['start']
        
    # load in total episode reward history
    data = np.loadtxt(logname)
    ave = moving_average(data,window_length)

    # create figure
    fig = plt.figure(figsize = (12,8))
    ax1 = fig.add_subplot(2,1,1)
    ax2 = fig.add_subplot(2,1,2)

    # plot total reward history
    ax1.plot(data)
    ax1.set_xlabel('episode',labelpad = 8,fontsize = 13)
    ax1.set_ylabel('total reward',fontsize = 13)
    
    ave[:window_length] = np.nan
    ax2.plot(ave,linewidth=3)
    ax2.set_xlabel('episode',labelpad = 8,fontsize = 13)
    ax2.set_ylabel('ave total reward',fontsize=13)
    plt.show()

# %% [markdown]
# # Run fitted Q-Learning algo

# %%
# feed in current directory name and savename = experiment name
dirname = os.getcwd()
savename = 'qfitted_cartpole_experiment_1'
gymname = 'CartPole-v1'

# initialize Q Learn process
num_episodes = 1000
explore_decay = 1
explore_val = 0.01
exit_level = 200
exit_window = 100
save_weight_freq = 1000

# initialize memory
episode_update = 1
memory_length = 1

# load into instance of learner
demo = QLearner(gymname,dirname,savename,num_episodes=num_episodes,explore_decay=explore_decay,explore_val=explore_val,memory_length=memory_length,episode_update=episode_update,exit_level=exit_level,exit_window=exit_window,save_weight_freq=save_weight_freq)

# initialize Q function
layer_sizes = [50,50]
alpha = 10**(-2)
activation = 'relu'
demo.initialize_Q(layer_sizes=layer_sizes,alpha=alpha,activation=activation)
# Out:
# WARN: gym.spaces.Box autodetected dtype as <class 'numpy.float32'>. Please provide explicit dtype.

# %%
demo.train()
# Out:
# episode 1 of 1000 complete,  explore val = 0.01, episode reward = 10.0, ave reward = 10.0
# episode 2 of 1000 complete,  explore val = 0.01, episode reward = 50.0, ave reward = 50.0
# episode 3 of 1000 complete,  explore val = 0.01, episode reward = 14.0, ave reward = 14.0
# episode 4 of 1000 complete,  explore val = 0.01, episode reward = 9.0, ave reward = 9.0
# episode 5 of 1000 complete,  explore val = 0.01, episode reward = 9.0, ave reward = 9.0
# episode 6 of 1000 complete,  explore val = 0.01, episode reward = 16.0, ave reward = 16.0
# episode 7 of 1000 complete,  explore val = 0.01, episode reward = 24.0, ave reward = 24.0
# episode 8 of 1000 complete,  explore val = 0.01, episode reward = 61.0, ave reward = 61.0
# episode 9 of 1000 complete,  explore val = 0.01, episode reward = 52.0, ave reward = 52.0
# episode 10 of 1000 complete,  explore val = 0.01, episode reward = 99.0, ave reward = 99.0
# episode 11 of 1000 complete,  explore val = 0.01, episode reward = 55.0, ave reward = 55.0
# episode 12 of 1000 complete,  explore val = 0.01, episode reward = 29.0, ave reward = 29.0
# episode 13 of 1000 complete,  explore val = 0.01, episode reward = 59.0, ave reward = 59.0
# episode 14 of 1000 complete,  explore val = 0.01, episode reward = 126.0, ave reward = 126.0
# episode 15 of 1000 complete,  explore val = 0.01, episode reward = 43.0, ave reward = 43.0
# episode 16 of 1000 complete,  explore val = 0.01, episode reward = 23.0, ave reward = 23.0
# episode 17 of 1000 complete,  explore val = 0.01, episode reward = 12.0, ave reward = 12.0
# episode 18 of 1000 complete,  explore val = 0.01, episode reward = 20.0, ave reward = 20.0
# episode 19 of 1000 complete,  explore val = 0.01, episode reward = 70.0, ave reward = 70.0
# episode 20 of 1000 complete,  explore val = 0.01, episode reward = 31.0, ave reward = 31.0
# episode 21 of 1000 complete,  explore val = 0.01, episode reward = 56.0, ave reward = 56.0
# episode 22 of 1000 complete,  explore val = 0.01, episode reward = 500.0, ave reward = 500.0
# episode 23 of 1000 complete,  explore val = 0.01, episode reward = 178.0, ave reward = 178.0
# episode 24 of 1000 complete,  explore val = 0.01, episode reward = 73.0, ave reward = 73.0
# episode 25 of 1000 complete,  explore val = 0.01, episode reward = 500.0, ave reward = 500.0
# episode 26 of 1000 complete,  explore val = 0.01, episode reward = 175.0, ave reward = 175.0
# episode 27 of 1000 complete,  explore val = 0.01, episode reward = 78.0, ave reward = 78.0
# episode 28 of 1000 complete,  explore val = 0.01, episode reward = 43.0, ave reward = 43.0
# episode 29 of 1000 complete,  explore val = 0.01, episode reward = 17.0, ave reward = 17.0
# episode 30 of 1000 complete,  explore val = 0.01, episode reward = 9.0, ave reward = 9.0
# episode 31 of 1000 complete,  explore val = 0.01, episode reward = 20.0, ave reward = 20.0
# episode 32 of 1000 complete,  explore val = 0.01, episode reward = 40.0, ave reward = 40.0
# episode 33 of 1000 complete,  explore val = 0.01, episode reward = 19.0, ave reward = 19.0
# episode 34 of 1000 complete,  explore val = 0.01, episode reward = 8.0, ave reward = 8.0
# episode 35 of 1000 complete,  explore val = 0.01, episode reward = 15.0, ave reward = 15.0
# episode 36 of 1000 complete,  explore val = 0.01, episode reward = 9.0, ave reward = 9.0
# episode 37 of 1000 complete,  explore val = 0.01, episode reward = 21.0, ave reward = 21.0
# episode 38 of 1000 complete,  explore val = 0.01, episode reward = 10.0, ave reward = 10.0
# episode 39 of 1000 complete,  explore val = 0.01, episode reward = 16.0, ave reward = 16.0
# episode 40 of 1000 complete,  explore val = 0.01, episode reward = 10.0, ave reward = 10.0
# episode 41 of 1000 complete,  explore val = 0.01, episode reward = 27.0, ave reward = 27.0
# episode 42 of 1000 complete,  explore val = 0.01, episode reward = 436.0, ave reward = 436.0
# episode 43 of 1000 complete,  explore val = 0.01, episode reward = 48.0, ave reward = 48.0
# episode 44 of 1000 complete,  explore val = 0.01, episode reward = 72.0, ave reward = 72.0
# episode 45 of 1000 complete,  explore val = 0.01, episode reward = 32.0, ave reward = 32.0
# episode 46 of 1000 complete,  explore val = 0.01, episode reward = 23.0, ave reward = 23.0
# episode 47 of 1000 complete,  explore val = 0.01, episode reward = 29.0, ave reward = 29.0
# episode 48 of 1000 complete,  explore val = 0.01, episode reward = 23.0, ave reward = 23.0
# episode 49 of 1000 complete,  explore val = 0.01, episode reward = 40.0, ave reward = 40.0
# episode 50 of 1000 complete,  explore val = 0.01, episode reward = 17.0, ave reward = 17.0
# episode 51 of 1000 complete,  explore val = 0.01, episode reward = 47.0, ave reward = 47.0
# episode 52 of 1000 complete,  explore val = 0.01, episode reward = 38.0, ave reward = 38.0
# episode 53 of 1000 complete,  explore val = 0.01, episode reward = 16.0, ave reward = 16.0
# episode 54 of 1000 complete,  explore val = 0.01, episode reward = 9.0, ave reward = 9.0
# episode 55 of 1000 complete,  explore val = 0.01, episode reward = 48.0, ave reward = 48.0
# episode 56 of 1000 complete,  explore val = 0.01, episode reward = 27.0, ave reward = 27.0
# episode 57 of 1000 complete,  explore val = 0.01, episode reward = 67.0, ave reward = 67.0
# episode 58 of 1000 complete,  explore val = 0.01, episode reward = 47.0, ave reward = 47.0
# episode 59 of 1000 complete,  explore val = 0.01, episode reward = 43.0, ave reward = 43.0
# episode 60 of 1000 complete,  explore val = 0.01, episode reward = 66.0, ave reward = 66.0
# episode 61 of 1000 complete,  explore val = 0.01, episode reward = 147.0, ave reward = 147.0
# episode 62 of 1000 complete,  explore val = 0.01, episode reward = 273.0, ave reward = 273.0
# episode 63 of 1000 complete,  explore val = 0.01, episode reward = 299.0, ave reward = 299.0
# episode 64 of 1000 complete,  explore val = 0.01, episode reward = 90.0, ave reward = 90.0
# episode 65 of 1000 complete,  explore val = 0.01, episode reward = 42.0, ave reward = 42.0
# episode 66 of 1000 complete,  explore val = 0.01, episode reward = 44.0, ave reward = 44.0
# episode 67 of 1000 complete,  explore val = 0.01, episode reward = 19.0, ave reward = 19.0
# episode 68 of 1000 complete,  explore val = 0.01, episode reward = 39.0, ave reward = 39.0
# episode 69 of 1000 complete,  explore val = 0.01, episode reward = 28.0, ave reward = 28.0
# episode 70 of 1000 complete,  explore val = 0.01, episode reward = 327.0, ave reward = 327.0
# episode 71 of 1000 complete,  explore val = 0.01, episode reward = 89.0, ave reward = 89.0
# episode 72 of 1000 complete,  explore val = 0.01, episode reward = 76.0, ave reward = 76.0
# episode 73 of 1000 complete,  explore val = 0.01, episode reward = 37.0, ave reward = 37.0
# episode 74 of 1000 complete,  explore val = 0.01, episode reward = 25.0, ave reward = 25.0
# episode 75 of 1000 complete,  explore val = 0.01, episode reward = 38.0, ave reward = 38.0
# episode 76 of 1000 complete,  explore val = 0.01, episode reward = 93.0, ave reward = 93.0
# episode 77 of 1000 complete,  explore val = 0.01, episode reward = 78.0, ave reward = 78.0
# episode 78 of 1000 complete,  explore val = 0.01, episode reward = 46.0, ave reward = 46.0
# episode 79 of 1000 complete,  explore val = 0.01, episode reward = 286.0, ave reward = 286.0
# episode 80 of 1000 complete,  explore val = 0.01, episode reward = 50.0, ave reward = 50.0
# episode 81 of 1000 complete,  explore val = 0.01, episode reward = 30.0, ave reward = 30.0
# episode 82 of 1000 complete,  explore val = 0.01, episode reward = 11.0, ave reward = 11.0
# episode 83 of 1000 complete,  explore val = 0.01, episode reward = 10.0, ave reward = 10.0
# episode 84 of 1000 complete,  explore val = 0.01, episode reward = 34.0, ave reward = 34.0
# episode 85 of 1000 complete,  explore val = 0.01, episode reward = 40.0, ave reward = 40.0
# episode 86 of 1000 complete,  explore val = 0.01, episode reward = 53.0, ave reward = 53.0
# episode 87 of 1000 complete,  explore val = 0.01, episode reward = 47.0, ave reward = 47.0
# episode 88 of 1000 complete,  explore val = 0.01, episode reward = 20.0, ave reward = 20.0
# episode 89 of 1000 complete,  explore val = 0.01, episode reward = 8.0, ave reward = 8.0
# episode 90 of 1000 complete,  explore val = 0.01, episode reward = 52.0, ave reward = 52.0
# episode 91 of 1000 complete,  explore val = 0.01, episode reward = 74.0, ave reward = 74.0
# episode 92 of 1000 complete,  explore val = 0.01, episode reward = 42.0, ave reward = 42.0
# episode 93 of 1000 complete,  explore val = 0.01, episode reward = 42.0, ave reward = 42.0
# episode 94 of 1000 complete,  explore val = 0.01, episode reward = 65.0, ave reward = 65.0
# episode 95 of 1000 complete,  explore val = 0.01, episode reward = 36.0, ave reward = 36.0
# episode 96 of 1000 complete,  explore val = 0.01, episode reward = 30.0, ave reward = 30.0
# episode 97 of 1000 complete,  explore val = 0.01, episode reward = 57.0, ave reward = 57.0
# episode 98 of 1000 complete,  explore val = 0.01, episode reward = 30.0, ave reward = 30.0
# episode 99 of 1000 complete,  explore val = 0.01, episode reward = 22.0, ave reward = 22.0
# episode 100 of 1000 complete,  explore val = 0.01, episode reward = 23.0, ave reward = 23.0
# episode 101 of 1000 complete,  explore val = 0.01, episode reward = 45.0, ave reward = 66.2
# episode 102 of 1000 complete,  explore val = 0.01, episode reward = 28.0, ave reward = 66.5
# episode 103 of 1000 complete,  explore val = 0.01, episode reward = 23.0, ave reward = 66.3
# episode 104 of 1000 complete,  explore val = 0.01, episode reward = 30.0, ave reward = 66.4
# episode 105 of 1000 complete,  explore val = 0.01, episode reward = 35.0, ave reward = 66.6
# episode 106 of 1000 complete,  explore val = 0.01, episode reward = 43.0, ave reward = 66.8
# episode 107 of 1000 complete,  explore val = 0.01, episode reward = 50.0, ave reward = 67.1
# episode 108 of 1000 complete,  explore val = 0.01, episode reward = 48.0, ave reward = 67.4
# episode 109 of 1000 complete,  explore val = 0.01, episode reward = 68.0, ave reward = 67.2
# episode 110 of 1000 complete,  explore val = 0.01, episode reward = 40.0, ave reward = 67.4
# episode 111 of 1000 complete,  explore val = 0.01, episode reward = 37.0, ave reward = 66.8
# episode 112 of 1000 complete,  explore val = 0.01, episode reward = 71.0, ave reward = 66.6
# episode 113 of 1000 complete,  explore val = 0.01, episode reward = 55.0, ave reward = 67.1
# episode 114 of 1000 complete,  explore val = 0.01, episode reward = 49.0, ave reward = 67.0
# episode 115 of 1000 complete,  explore val = 0.01, episode reward = 65.0, ave reward = 66.2
# episode 116 of 1000 complete,  explore val = 0.01, episode reward = 71.0, ave reward = 66.5
# episode 117 of 1000 complete,  explore val = 0.01, episode reward = 57.0, ave reward = 67.0
# episode 118 of 1000 complete,  explore val = 0.01, episode reward = 75.0, ave reward = 67.4
# episode 119 of 1000 complete,  explore val = 0.01, episode reward = 37.0, ave reward = 68.0
# episode 120 of 1000 complete,  explore val = 0.01, episode reward = 38.0, ave reward = 67.6
# episode 121 of 1000 complete,  explore val = 0.01, episode reward = 43.0, ave reward = 67.7
# episode 122 of 1000 complete,  explore val = 0.01, episode reward = 30.0, ave reward = 67.6
# episode 123 of 1000 complete,  explore val = 0.01, episode reward = 60.0, ave reward = 62.9
# episode 124 of 1000 complete,  explore val = 0.01, episode reward = 44.0, ave reward = 61.7
# episode 125 of 1000 complete,  explore val = 0.01, episode reward = 18.0, ave reward = 61.4
# episode 126 of 1000 complete,  explore val = 0.01, episode reward = 15.0, ave reward = 56.6
# episode 127 of 1000 complete,  explore val = 0.01, episode reward = 81.0, ave reward = 55.0
# episode 128 of 1000 complete,  explore val = 0.01, episode reward = 80.0, ave reward = 55.0
# episode 129 of 1000 complete,  explore val = 0.01, episode reward = 259.0, ave reward = 55.4
# episode 130 of 1000 complete,  explore val = 0.01, episode reward = 54.0, ave reward = 57.8
# episode 131 of 1000 complete,  explore val = 0.01, episode reward = 76.0, ave reward = 58.2
# episode 132 of 1000 complete,  explore val = 0.01, episode reward = 152.0, ave reward = 58.8
# episode 133 of 1000 complete,  explore val = 0.01, episode reward = 79.0, ave reward = 59.9
# episode 134 of 1000 complete,  explore val = 0.01, episode reward = 58.0, ave reward = 60.5
# episode 135 of 1000 complete,  explore val = 0.01, episode reward = 114.0, ave reward = 61.0
# episode 136 of 1000 complete,  explore val = 0.01, episode reward = 63.0, ave reward = 62.0
# episode 137 of 1000 complete,  explore val = 0.01, episode reward = 49.0, ave reward = 62.6
# episode 138 of 1000 complete,  explore val = 0.01, episode reward = 60.0, ave reward = 62.8
# episode 139 of 1000 complete,  explore val = 0.01, episode reward = 60.0, ave reward = 63.3
# episode 140 of 1000 complete,  explore val = 0.01, episode reward = 69.0, ave reward = 63.8
# episode 141 of 1000 complete,  explore val = 0.01, episode reward = 68.0, ave reward = 64.4
# episode 142 of 1000 complete,  explore val = 0.01, episode reward = 72.0, ave reward = 64.8
# episode 143 of 1000 complete,  explore val = 0.01, episode reward = 61.0, ave reward = 61.1
# episode 144 of 1000 complete,  explore val = 0.01, episode reward = 33.0, ave reward = 61.3
# episode 145 of 1000 complete,  explore val = 0.01, episode reward = 33.0, ave reward = 60.9
# episode 146 of 1000 complete,  explore val = 0.01, episode reward = 26.0, ave reward = 60.9
# episode 147 of 1000 complete,  explore val = 0.01, episode reward = 73.0, ave reward = 60.9
# episode 148 of 1000 complete,  explore val = 0.01, episode reward = 27.0, ave reward = 61.4
# episode 149 of 1000 complete,  explore val = 0.01, episode reward = 26.0, ave reward = 61.4
# episode 150 of 1000 complete,  explore val = 0.01, episode reward = 59.0, ave reward = 61.2
# episode 151 of 1000 complete,  explore val = 0.01, episode reward = 331.0, ave reward = 61.7
# episode 152 of 1000 complete,  explore val = 0.01, episode reward = 368.0, ave reward = 64.5
# episode 153 of 1000 complete,  explore val = 0.01, episode reward = 120.0, ave reward = 67.8
# episode 154 of 1000 complete,  explore val = 0.01, episode reward = 72.0, ave reward = 68.8
# episode 155 of 1000 complete,  explore val = 0.01, episode reward = 294.0, ave reward = 69.5
# episode 156 of 1000 complete,  explore val = 0.01, episode reward = 64.0, ave reward = 71.9
# episode 157 of 1000 complete,  explore val = 0.01, episode reward = 82.0, ave reward = 72.3
# episode 158 of 1000 complete,  explore val = 0.01, episode reward = 107.0, ave reward = 72.5
# episode 159 of 1000 complete,  explore val = 0.01, episode reward = 117.0, ave reward = 73.1
# episode 160 of 1000 complete,  explore val = 0.01, episode reward = 94.0, ave reward = 73.8
# episode 161 of 1000 complete,  explore val = 0.01, episode reward = 376.0, ave reward = 74.1
# episode 162 of 1000 complete,  explore val = 0.01, episode reward = 175.0, ave reward = 76.4
# episode 163 of 1000 complete,  explore val = 0.01, episode reward = 156.0, ave reward = 75.4
# episode 164 of 1000 complete,  explore val = 0.01, episode reward = 379.0, ave reward = 74.0
# episode 165 of 1000 complete,  explore val = 0.01, episode reward = 382.0, ave reward = 76.8
# episode 166 of 1000 complete,  explore val = 0.01, episode reward = 94.0, ave reward = 80.2
# episode 167 of 1000 complete,  explore val = 0.01, episode reward = 75.0, ave reward = 80.8
# episode 168 of 1000 complete,  explore val = 0.01, episode reward = 80.0, ave reward = 81.3
# episode 169 of 1000 complete,  explore val = 0.01, episode reward = 95.0, ave reward = 81.7
# episode 170 of 1000 complete,  explore val = 0.01, episode reward = 112.0, ave reward = 82.4
# episode 171 of 1000 complete,  explore val = 0.01, episode reward = 500.0, ave reward = 80.2
# episode 172 of 1000 complete,  explore val = 0.01, episode reward = 178.0, ave reward = 84.4
# episode 173 of 1000 complete,  explore val = 0.01, episode reward = 337.0, ave reward = 85.4
# episode 174 of 1000 complete,  explore val = 0.01, episode reward = 155.0, ave reward = 88.4
# episode 175 of 1000 complete,  explore val = 0.01, episode reward = 206.0, ave reward = 89.7
# episode 176 of 1000 complete,  explore val = 0.01, episode reward = 178.0, ave reward = 91.4
# episode 177 of 1000 complete,  explore val = 0.01, episode reward = 254.0, ave reward = 92.2
# episode 178 of 1000 complete,  explore val = 0.01, episode reward = 193.0, ave reward = 94.0
# episode 179 of 1000 complete,  explore val = 0.01, episode reward = 151.0, ave reward = 95.4
# episode 180 of 1000 complete,  explore val = 0.01, episode reward = 224.0, ave reward = 94.1
# episode 181 of 1000 complete,  explore val = 0.01, episode reward = 221.0, ave reward = 95.8
# episode 182 of 1000 complete,  explore val = 0.01, episode reward = 152.0, ave reward = 97.7
# episode 183 of 1000 complete,  explore val = 0.01, episode reward = 500.0, ave reward = 99.1
# episode 184 of 1000 complete,  explore val = 0.01, episode reward = 245.0, ave reward = 104.0
# episode 185 of 1000 complete,  explore val = 0.01, episode reward = 208.0, ave reward = 106.2
# episode 186 of 1000 complete,  explore val = 0.01, episode reward = 176.0, ave reward = 107.8
# episode 187 of 1000 complete,  explore val = 0.01, episode reward = 213.0, ave reward = 109.1
# episode 188 of 1000 complete,  explore val = 0.01, episode reward = 286.0, ave reward = 110.7
# episode 189 of 1000 complete,  explore val = 0.01, episode reward = 254.0, ave reward = 113.4
# episode 190 of 1000 complete,  explore val = 0.01, episode reward = 243.0, ave reward = 115.8
# episode 191 of 1000 complete,  explore val = 0.01, episode reward = 209.0, ave reward = 117.8
# episode 192 of 1000 complete,  explore val = 0.01, episode reward = 500.0, ave reward = 119.1
# episode 193 of 1000 complete,  explore val = 0.01, episode reward = 330.0, ave reward = 123.7
# episode 194 of 1000 complete,  explore val = 0.01, episode reward = 251.0, ave reward = 126.6
# episode 195 of 1000 complete,  explore val = 0.01, episode reward = 175.0, ave reward = 128.4
# episode 196 of 1000 complete,  explore val = 0.01, episode reward = 500.0, ave reward = 129.8
# episode 197 of 1000 complete,  explore val = 0.01, episode reward = 307.0, ave reward = 134.5
# episode 198 of 1000 complete,  explore val = 0.01, episode reward = 500.0, ave reward = 137.0
# episode 199 of 1000 complete,  explore val = 0.01, episode reward = 337.0, ave reward = 141.7
# episode 200 of 1000 complete,  explore val = 0.01, episode reward = 101.0, ave reward = 144.9
# episode 201 of 1000 complete,  explore val = 0.01, episode reward = 402.0, ave reward = 145.6
# episode 202 of 1000 complete,  explore val = 0.01, episode reward = 270.0, ave reward = 149.2
# episode 203 of 1000 complete,  explore val = 0.01, episode reward = 261.0, ave reward = 151.6
# episode 204 of 1000 complete,  explore val = 0.01, episode reward = 102.0, ave reward = 154.0
# episode 205 of 1000 complete,  explore val = 0.01, episode reward = 11.0, ave reward = 154.7
# episode 206 of 1000 complete,  explore val = 0.01, episode reward = 10.0, ave reward = 154.5
# episode 207 of 1000 complete,  explore val = 0.01, episode reward = 214.0, ave reward = 154.2
# episode 208 of 1000 complete,  explore val = 0.01, episode reward = 67.0, ave reward = 155.8
# episode 209 of 1000 complete,  explore val = 0.01, episode reward = 62.0, ave reward = 156.0
# episode 210 of 1000 complete,  explore val = 0.01, episode reward = 28.0, ave reward = 155.9
# episode 211 of 1000 complete,  explore val = 0.01, episode reward = 207.0, ave reward = 155.8
# episode 212 of 1000 complete,  explore val = 0.01, episode reward = 311.0, ave reward = 157.5
# episode 213 of 1000 complete,  explore val = 0.01, episode reward = 165.0, ave reward = 159.9
# episode 214 of 1000 complete,  explore val = 0.01, episode reward = 241.0, ave reward = 161.0
# episode 215 of 1000 complete,  explore val = 0.01, episode reward = 141.0, ave reward = 162.9
# episode 216 of 1000 complete,  explore val = 0.01, episode reward = 131.0, ave reward = 163.7
# episode 217 of 1000 complete,  explore val = 0.01, episode reward = 128.0, ave reward = 164.3
# episode 218 of 1000 complete,  explore val = 0.01, episode reward = 97.0, ave reward = 165.0
# episode 219 of 1000 complete,  explore val = 0.01, episode reward = 121.0, ave reward = 165.2
# episode 220 of 1000 complete,  explore val = 0.01, episode reward = 97.0, ave reward = 166.1
# episode 221 of 1000 complete,  explore val = 0.01, episode reward = 114.0, ave reward = 166.6
# episode 222 of 1000 complete,  explore val = 0.01, episode reward = 95.0, ave reward = 167.4
# episode 223 of 1000 complete,  explore val = 0.01, episode reward = 100.0, ave reward = 168.0
# episode 224 of 1000 complete,  explore val = 0.01, episode reward = 111.0, ave reward = 168.4
# episode 225 of 1000 complete,  explore val = 0.01, episode reward = 95.0, ave reward = 169.1
# episode 226 of 1000 complete,  explore val = 0.01, episode reward = 86.0, ave reward = 169.8
# episode 227 of 1000 complete,  explore val = 0.01, episode reward = 88.0, ave reward = 170.6
# episode 228 of 1000 complete,  explore val = 0.01, episode reward = 84.0, ave reward = 170.6
# episode 229 of 1000 complete,  explore val = 0.01, episode reward = 71.0, ave reward = 170.7
# episode 230 of 1000 complete,  explore val = 0.01, episode reward = 58.0, ave reward = 168.8
# episode 231 of 1000 complete,  explore val = 0.01, episode reward = 44.0, ave reward = 168.8
# episode 232 of 1000 complete,  explore val = 0.01, episode reward = 28.0, ave reward = 168.5
# episode 233 of 1000 complete,  explore val = 0.01, episode reward = 25.0, ave reward = 167.3
# episode 234 of 1000 complete,  explore val = 0.01, episode reward = 98.0, ave reward = 166.7
# episode 235 of 1000 complete,  explore val = 0.01, episode reward = 24.0, ave reward = 167.1
# episode 236 of 1000 complete,  explore val = 0.01, episode reward = 24.0, ave reward = 166.2
# episode 237 of 1000 complete,  explore val = 0.01, episode reward = 26.0, ave reward = 165.8
# episode 238 of 1000 complete,  explore val = 0.01, episode reward = 27.0, ave reward = 165.6
# episode 239 of 1000 complete,  explore val = 0.01, episode reward = 40.0, ave reward = 165.3
# episode 240 of 1000 complete,  explore val = 0.01, episode reward = 101.0, ave reward = 165.1
# episode 241 of 1000 complete,  explore val = 0.01, episode reward = 135.0, ave reward = 165.4
# episode 242 of 1000 complete,  explore val = 0.01, episode reward = 89.0, ave reward = 166.1
# episode 243 of 1000 complete,  explore val = 0.01, episode reward = 129.0, ave reward = 166.2
# episode 244 of 1000 complete,  explore val = 0.01, episode reward = 108.0, ave reward = 166.9
# episode 245 of 1000 complete,  explore val = 0.01, episode reward = 122.0, ave reward = 167.7
# episode 246 of 1000 complete,  explore val = 0.01, episode reward = 116.0, ave reward = 168.6
# episode 247 of 1000 complete,  explore val = 0.01, episode reward = 124.0, ave reward = 169.5
# episode 248 of 1000 complete,  explore val = 0.01, episode reward = 133.0, ave reward = 170.0
# episode 249 of 1000 complete,  explore val = 0.01, episode reward = 119.0, ave reward = 171.0
# episode 250 of 1000 complete,  explore val = 0.01, episode reward = 113.0, ave reward = 172.0
# episode 251 of 1000 complete,  explore val = 0.01, episode reward = 132.0, ave reward = 172.5
# episode 252 of 1000 complete,  explore val = 0.01, episode reward = 119.0, ave reward = 170.5
# episode 253 of 1000 complete,  explore val = 0.01, episode reward = 141.0, ave reward = 168.0
# episode 254 of 1000 complete,  explore val = 0.01, episode reward = 104.0, ave reward = 168.2
# episode 255 of 1000 complete,  explore val = 0.01, episode reward = 130.0, ave reward = 168.6
# episode 256 of 1000 complete,  explore val = 0.01, episode reward = 113.0, ave reward = 166.9
# episode 257 of 1000 complete,  explore val = 0.01, episode reward = 122.0, ave reward = 167.4
# episode 258 of 1000 complete,  explore val = 0.01, episode reward = 139.0, ave reward = 167.8
# episode 259 of 1000 complete,  explore val = 0.01, episode reward = 108.0, ave reward = 168.1
# episode 260 of 1000 complete,  explore val = 0.01, episode reward = 127.0, ave reward = 168.0
# episode 261 of 1000 complete,  explore val = 0.01, episode reward = 127.0, ave reward = 168.4
# episode 262 of 1000 complete,  explore val = 0.01, episode reward = 145.0, ave reward = 165.9
# episode 263 of 1000 complete,  explore val = 0.01, episode reward = 119.0, ave reward = 165.6
# episode 264 of 1000 complete,  explore val = 0.01, episode reward = 120.0, ave reward = 165.2
# episode 265 of 1000 complete,  explore val = 0.01, episode reward = 96.0, ave reward = 162.6
# episode 266 of 1000 complete,  explore val = 0.01, episode reward = 125.0, ave reward = 159.8
# episode 267 of 1000 complete,  explore val = 0.01, episode reward = 108.0, ave reward = 160.1
# episode 268 of 1000 complete,  explore val = 0.01, episode reward = 120.0, ave reward = 160.4
# episode 269 of 1000 complete,  explore val = 0.01, episode reward = 122.0, ave reward = 160.8
# episode 270 of 1000 complete,  explore val = 0.01, episode reward = 103.0, ave reward = 161.1
# episode 271 of 1000 complete,  explore val = 0.01, episode reward = 234.0, ave reward = 161.0
# episode 272 of 1000 complete,  explore val = 0.01, episode reward = 93.0, ave reward = 158.3
# episode 273 of 1000 complete,  explore val = 0.01, episode reward = 122.0, ave reward = 157.5
# episode 274 of 1000 complete,  explore val = 0.01, episode reward = 142.0, ave reward = 155.3
# episode 275 of 1000 complete,  explore val = 0.01, episode reward = 107.0, ave reward = 155.2
# episode 276 of 1000 complete,  explore val = 0.01, episode reward = 138.0, ave reward = 154.2
# episode 277 of 1000 complete,  explore val = 0.01, episode reward = 121.0, ave reward = 153.8
# episode 278 of 1000 complete,  explore val = 0.01, episode reward = 132.0, ave reward = 152.5
# episode 279 of 1000 complete,  explore val = 0.01, episode reward = 146.0, ave reward = 151.8
# episode 280 of 1000 complete,  explore val = 0.01, episode reward = 132.0, ave reward = 151.8
# episode 281 of 1000 complete,  explore val = 0.01, episode reward = 142.0, ave reward = 150.9
# episode 282 of 1000 complete,  explore val = 0.01, episode reward = 133.0, ave reward = 150.1
# episode 283 of 1000 complete,  explore val = 0.01, episode reward = 113.0, ave reward = 149.9
# episode 284 of 1000 complete,  explore val = 0.01, episode reward = 106.0, ave reward = 146.0
# episode 285 of 1000 complete,  explore val = 0.01, episode reward = 153.0, ave reward = 144.6
# episode 286 of 1000 complete,  explore val = 0.01, episode reward = 103.0, ave reward = 144.1
# episode 287 of 1000 complete,  explore val = 0.01, episode reward = 160.0, ave reward = 143.4
# episode 288 of 1000 complete,  explore val = 0.01, episode reward = 106.0, ave reward = 142.8
# episode 289 of 1000 complete,  explore val = 0.01, episode reward = 14.0, ave reward = 141.0
# episode 290 of 1000 complete,  explore val = 0.01, episode reward = 121.0, ave reward = 138.6
# episode 291 of 1000 complete,  explore val = 0.01, episode reward = 107.0, ave reward = 137.4
# episode 292 of 1000 complete,  explore val = 0.01, episode reward = 18.0, ave reward = 136.4
# episode 293 of 1000 complete,  explore val = 0.01, episode reward = 26.0, ave reward = 131.6
# episode 294 of 1000 complete,  explore val = 0.01, episode reward = 115.0, ave reward = 128.5
# episode 295 of 1000 complete,  explore val = 0.01, episode reward = 204.0, ave reward = 127.2
# episode 296 of 1000 complete,  explore val = 0.01, episode reward = 141.0, ave reward = 127.5
# episode 297 of 1000 complete,  explore val = 0.01, episode reward = 155.0, ave reward = 123.9
# episode 298 of 1000 complete,  explore val = 0.01, episode reward = 152.0, ave reward = 122.4
# episode 299 of 1000 complete,  explore val = 0.01, episode reward = 168.0, ave reward = 118.9
# episode 300 of 1000 complete,  explore val = 0.01, episode reward = 22.0, ave reward = 117.2
# episode 301 of 1000 complete,  explore val = 0.01, episode reward = 119.0, ave reward = 116.4
# episode 302 of 1000 complete,  explore val = 0.01, episode reward = 270.0, ave reward = 113.6
# episode 303 of 1000 complete,  explore val = 0.01, episode reward = 152.0, ave reward = 113.6
# episode 304 of 1000 complete,  explore val = 0.01, episode reward = 243.0, ave reward = 112.5
# episode 305 of 1000 complete,  explore val = 0.01, episode reward = 195.0, ave reward = 113.9
# episode 306 of 1000 complete,  explore val = 0.01, episode reward = 329.0, ave reward = 115.7
# episode 307 of 1000 complete,  explore val = 0.01, episode reward = 182.0, ave reward = 118.9
# episode 308 of 1000 complete,  explore val = 0.01, episode reward = 500.0, ave reward = 118.6
# episode 309 of 1000 complete,  explore val = 0.01, episode reward = 188.0, ave reward = 122.9
# episode 310 of 1000 complete,  explore val = 0.01, episode reward = 500.0, ave reward = 124.2
# episode 311 of 1000 complete,  explore val = 0.01, episode reward = 181.0, ave reward = 128.9
# episode 312 of 1000 complete,  explore val = 0.01, episode reward = 500.0, ave reward = 128.6
# episode 313 of 1000 complete,  explore val = 0.01, episode reward = 229.0, ave reward = 130.5
# episode 314 of 1000 complete,  explore val = 0.01, episode reward = 500.0, ave reward = 131.2
# episode 315 of 1000 complete,  explore val = 0.01, episode reward = 197.0, ave reward = 133.8
# episode 316 of 1000 complete,  explore val = 0.01, episode reward = 197.0, ave reward = 134.3
# episode 317 of 1000 complete,  explore val = 0.01, episode reward = 177.0, ave reward = 135.0
# episode 318 of 1000 complete,  explore val = 0.01, episode reward = 201.0, ave reward = 135.5
# episode 319 of 1000 complete,  explore val = 0.01, episode reward = 196.0, ave reward = 136.5
# episode 320 of 1000 complete,  explore val = 0.01, episode reward = 500.0, ave reward = 137.3
# episode 321 of 1000 complete,  explore val = 0.01, episode reward = 277.0, ave reward = 141.3
# episode 322 of 1000 complete,  explore val = 0.01, episode reward = 500.0, ave reward = 142.9
# episode 323 of 1000 complete,  explore val = 0.01, episode reward = 197.0, ave reward = 147.0
# episode 324 of 1000 complete,  explore val = 0.01, episode reward = 305.0, ave reward = 147.9
# episode 325 of 1000 complete,  explore val = 0.01, episode reward = 221.0, ave reward = 149.9
# episode 326 of 1000 complete,  explore val = 0.01, episode reward = 263.0, ave reward = 151.1
# episode 327 of 1000 complete,  explore val = 0.01, episode reward = 240.0, ave reward = 152.9
# episode 328 of 1000 complete,  explore val = 0.01, episode reward = 174.0, ave reward = 154.4
# episode 329 of 1000 complete,  explore val = 0.01, episode reward = 140.0, ave reward = 155.3
# episode 330 of 1000 complete,  explore val = 0.01, episode reward = 156.0, ave reward = 156.0
# episode 331 of 1000 complete,  explore val = 0.01, episode reward = 93.0, ave reward = 157.0
# episode 332 of 1000 complete,  explore val = 0.01, episode reward = 106.0, ave reward = 157.5
# episode 333 of 1000 complete,  explore val = 0.01, episode reward = 128.0, ave reward = 158.3
# episode 334 of 1000 complete,  explore val = 0.01, episode reward = 80.0, ave reward = 159.3
# episode 335 of 1000 complete,  explore val = 0.01, episode reward = 26.0, ave reward = 159.1
# episode 336 of 1000 complete,  explore val = 0.01, episode reward = 136.0, ave reward = 159.1
# episode 337 of 1000 complete,  explore val = 0.01, episode reward = 223.0, ave reward = 160.3
# episode 338 of 1000 complete,  explore val = 0.01, episode reward = 13.0, ave reward = 162.2
# episode 339 of 1000 complete,  explore val = 0.01, episode reward = 138.0, ave reward = 162.1
# episode 340 of 1000 complete,  explore val = 0.01, episode reward = 202.0, ave reward = 163.1
# episode 341 of 1000 complete,  explore val = 0.01, episode reward = 157.0, ave reward = 164.1
# episode 342 of 1000 complete,  explore val = 0.01, episode reward = 121.0, ave reward = 164.3
# episode 343 of 1000 complete,  explore val = 0.01, episode reward = 127.0, ave reward = 164.6
# episode 344 of 1000 complete,  explore val = 0.01, episode reward = 123.0, ave reward = 164.6
# episode 345 of 1000 complete,  explore val = 0.01, episode reward = 220.0, ave reward = 164.8
# episode 346 of 1000 complete,  explore val = 0.01, episode reward = 122.0, ave reward = 165.7
# episode 347 of 1000 complete,  explore val = 0.01, episode reward = 198.0, ave reward = 165.8
# episode 348 of 1000 complete,  explore val = 0.01, episode reward = 172.0, ave reward = 166.5
# episode 349 of 1000 complete,  explore val = 0.01, episode reward = 183.0, ave reward = 166.9
# episode 350 of 1000 complete,  explore val = 0.01, episode reward = 129.0, ave reward = 167.6
# episode 351 of 1000 complete,  explore val = 0.01, episode reward = 234.0, ave reward = 167.7
# episode 352 of 1000 complete,  explore val = 0.01, episode reward = 185.0, ave reward = 168.7
# episode 353 of 1000 complete,  explore val = 0.01, episode reward = 136.0, ave reward = 169.4
# episode 354 of 1000 complete,  explore val = 0.01, episode reward = 116.0, ave reward = 169.4
# episode 355 of 1000 complete,  explore val = 0.01, episode reward = 230.0, ave reward = 169.5
# episode 356 of 1000 complete,  explore val = 0.01, episode reward = 128.0, ave reward = 170.5
# episode 357 of 1000 complete,  explore val = 0.01, episode reward = 128.0, ave reward = 170.6
# episode 358 of 1000 complete,  explore val = 0.01, episode reward = 112.0, ave reward = 170.7
# episode 359 of 1000 complete,  explore val = 0.01, episode reward = 104.0, ave reward = 170.4
# episode 360 of 1000 complete,  explore val = 0.01, episode reward = 107.0, ave reward = 170.4
# episode 361 of 1000 complete,  explore val = 0.01, episode reward = 104.0, ave reward = 170.2
# episode 362 of 1000 complete,  explore val = 0.01, episode reward = 125.0, ave reward = 169.9
# episode 363 of 1000 complete,  explore val = 0.01, episode reward = 105.0, ave reward = 169.7
# episode 364 of 1000 complete,  explore val = 0.01, episode reward = 110.0, ave reward = 169.6
# episode 365 of 1000 complete,  explore val = 0.01, episode reward = 100.0, ave reward = 169.5
# episode 366 of 1000 complete,  explore val = 0.01, episode reward = 109.0, ave reward = 169.5
# episode 367 of 1000 complete,  explore val = 0.01, episode reward = 116.0, ave reward = 169.4
# episode 368 of 1000 complete,  explore val = 0.01, episode reward = 108.0, ave reward = 169.5
# episode 369 of 1000 complete,  explore val = 0.01, episode reward = 113.0, ave reward = 169.3
# episode 370 of 1000 complete,  explore val = 0.01, episode reward = 113.0, ave reward = 169.2
# episode 371 of 1000 complete,  explore val = 0.01, episode reward = 104.0, ave reward = 169.4
# episode 372 of 1000 complete,  explore val = 0.01, episode reward = 21.0, ave reward = 168.0
# episode 373 of 1000 complete,  explore val = 0.01, episode reward = 55.0, ave reward = 167.3
# episode 374 of 1000 complete,  explore val = 0.01, episode reward = 83.0, ave reward = 166.7
# episode 375 of 1000 complete,  explore val = 0.01, episode reward = 126.0, ave reward = 166.1
# episode 376 of 1000 complete,  explore val = 0.01, episode reward = 131.0, ave reward = 166.3
# episode 377 of 1000 complete,  explore val = 0.01, episode reward = 87.0, ave reward = 166.2
# episode 378 of 1000 complete,  explore val = 0.01, episode reward = 112.0, ave reward = 165.8
# episode 379 of 1000 complete,  explore val = 0.01, episode reward = 48.0, ave reward = 165.6
# episode 380 of 1000 complete,  explore val = 0.01, episode reward = 49.0, ave reward = 164.7
# episode 381 of 1000 complete,  explore val = 0.01, episode reward = 61.0, ave reward = 163.8
# episode 382 of 1000 complete,  explore val = 0.01, episode reward = 97.0, ave reward = 163.0
# episode 383 of 1000 complete,  explore val = 0.01, episode reward = 133.0, ave reward = 162.7
# episode 384 of 1000 complete,  explore val = 0.01, episode reward = 154.0, ave reward = 162.9
# episode 385 of 1000 complete,  explore val = 0.01, episode reward = 110.0, ave reward = 163.4
# episode 386 of 1000 complete,  explore val = 0.01, episode reward = 92.0, ave reward = 162.9
# episode 387 of 1000 complete,  explore val = 0.01, episode reward = 159.0, ave reward = 162.8
# episode 388 of 1000 complete,  explore val = 0.01, episode reward = 144.0, ave reward = 162.8
# episode 389 of 1000 complete,  explore val = 0.01, episode reward = 142.0, ave reward = 163.2
# episode 390 of 1000 complete,  explore val = 0.01, episode reward = 149.0, ave reward = 164.5
# episode 391 of 1000 complete,  explore val = 0.01, episode reward = 142.0, ave reward = 164.7
# episode 392 of 1000 complete,  explore val = 0.01, episode reward = 144.0, ave reward = 165.1
# episode 393 of 1000 complete,  explore val = 0.01, episode reward = 145.0, ave reward = 166.4
# episode 394 of 1000 complete,  explore val = 0.01, episode reward = 140.0, ave reward = 167.5
# episode 395 of 1000 complete,  explore val = 0.01, episode reward = 138.0, ave reward = 167.8
# episode 396 of 1000 complete,  explore val = 0.01, episode reward = 146.0, ave reward = 167.1
# episode 397 of 1000 complete,  explore val = 0.01, episode reward = 163.0, ave reward = 167.2
# episode 398 of 1000 complete,  explore val = 0.01, episode reward = 165.0, ave reward = 167.3
# episode 399 of 1000 complete,  explore val = 0.01, episode reward = 141.0, ave reward = 167.4
# episode 400 of 1000 complete,  explore val = 0.01, episode reward = 179.0, ave reward = 167.1
# episode 401 of 1000 complete,  explore val = 0.01, episode reward = 180.0, ave reward = 168.7
# episode 402 of 1000 complete,  explore val = 0.01, episode reward = 276.0, ave reward = 169.3
# episode 403 of 1000 complete,  explore val = 0.01, episode reward = 135.0, ave reward = 169.4
# episode 404 of 1000 complete,  explore val = 0.01, episode reward = 192.0, ave reward = 169.2
# episode 405 of 1000 complete,  explore val = 0.01, episode reward = 247.0, ave reward = 168.7
# episode 406 of 1000 complete,  explore val = 0.01, episode reward = 249.0, ave reward = 169.2
# episode 407 of 1000 complete,  explore val = 0.01, episode reward = 218.0, ave reward = 168.4
# episode 408 of 1000 complete,  explore val = 0.01, episode reward = 150.0, ave reward = 168.8
# episode 409 of 1000 complete,  explore val = 0.01, episode reward = 16.0, ave reward = 165.3
# episode 410 of 1000 complete,  explore val = 0.01, episode reward = 150.0, ave reward = 163.5
# episode 411 of 1000 complete,  explore val = 0.01, episode reward = 190.0, ave reward = 160.0
# episode 412 of 1000 complete,  explore val = 0.01, episode reward = 324.0, ave reward = 160.1
# episode 413 of 1000 complete,  explore val = 0.01, episode reward = 304.0, ave reward = 158.4
# episode 414 of 1000 complete,  explore val = 0.01, episode reward = 225.0, ave reward = 159.1
# episode 415 of 1000 complete,  explore val = 0.01, episode reward = 300.0, ave reward = 156.4
# episode 416 of 1000 complete,  explore val = 0.01, episode reward = 119.0, ave reward = 157.4
# episode 417 of 1000 complete,  explore val = 0.01, episode reward = 59.0, ave reward = 156.6
# episode 418 of 1000 complete,  explore val = 0.01, episode reward = 28.0, ave reward = 155.4
# episode 419 of 1000 complete,  explore val = 0.01, episode reward = 93.0, ave reward = 153.7
# episode 420 of 1000 complete,  explore val = 0.01, episode reward = 95.0, ave reward = 152.7
# episode 421 of 1000 complete,  explore val = 0.01, episode reward = 71.0, ave reward = 148.6
# episode 422 of 1000 complete,  explore val = 0.01, episode reward = 85.0, ave reward = 146.6
# episode 423 of 1000 complete,  explore val = 0.01, episode reward = 154.0, ave reward = 142.4
# episode 424 of 1000 complete,  explore val = 0.01, episode reward = 159.0, ave reward = 142.0
# episode 425 of 1000 complete,  explore val = 0.01, episode reward = 148.0, ave reward = 140.5
# episode 426 of 1000 complete,  explore val = 0.01, episode reward = 156.0, ave reward = 139.8
# episode 427 of 1000 complete,  explore val = 0.01, episode reward = 118.0, ave reward = 138.7
# episode 428 of 1000 complete,  explore val = 0.01, episode reward = 125.0, ave reward = 137.5
# episode 429 of 1000 complete,  explore val = 0.01, episode reward = 169.0, ave reward = 137.0
# episode 430 of 1000 complete,  explore val = 0.01, episode reward = 144.0, ave reward = 137.3
# episode 431 of 1000 complete,  explore val = 0.01, episode reward = 155.0, ave reward = 137.2
# episode 432 of 1000 complete,  explore val = 0.01, episode reward = 129.0, ave reward = 137.8
# episode 433 of 1000 complete,  explore val = 0.01, episode reward = 196.0, ave reward = 138.0
# episode 434 of 1000 complete,  explore val = 0.01, episode reward = 131.0, ave reward = 138.7
# episode 435 of 1000 complete,  explore val = 0.01, episode reward = 144.0, ave reward = 139.2
# episode 436 of 1000 complete,  explore val = 0.01, episode reward = 118.0, ave reward = 140.4
# episode 437 of 1000 complete,  explore val = 0.01, episode reward = 160.0, ave reward = 140.2
# episode 438 of 1000 complete,  explore val = 0.01, episode reward = 136.0, ave reward = 139.6
# episode 439 of 1000 complete,  explore val = 0.01, episode reward = 114.0, ave reward = 140.8
# episode 440 of 1000 complete,  explore val = 0.01, episode reward = 116.0, ave reward = 140.6
# episode 441 of 1000 complete,  explore val = 0.01, episode reward = 124.0, ave reward = 139.7
# episode 442 of 1000 complete,  explore val = 0.01, episode reward = 117.0, ave reward = 139.4
# episode 443 of 1000 complete,  explore val = 0.01, episode reward = 116.0, ave reward = 139.4
# episode 444 of 1000 complete,  explore val = 0.01, episode reward = 123.0, ave reward = 139.2
# episode 445 of 1000 complete,  explore val = 0.01, episode reward = 115.0, ave reward = 139.2
# episode 446 of 1000 complete,  explore val = 0.01, episode reward = 121.0, ave reward = 138.2
# episode 447 of 1000 complete,  explore val = 0.01, episode reward = 114.0, ave reward = 138.2
# episode 448 of 1000 complete,  explore val = 0.01, episode reward = 144.0, ave reward = 137.4
# episode 449 of 1000 complete,  explore val = 0.01, episode reward = 17.0, ave reward = 137.1
# episode 450 of 1000 complete,  explore val = 0.01, episode reward = 107.0, ave reward = 135.4
# episode 451 of 1000 complete,  explore val = 0.01, episode reward = 130.0, ave reward = 135.2
# episode 452 of 1000 complete,  explore val = 0.01, episode reward = 156.0, ave reward = 134.2
# episode 453 of 1000 complete,  explore val = 0.01, episode reward = 127.0, ave reward = 133.9
# episode 454 of 1000 complete,  explore val = 0.01, episode reward = 128.0, ave reward = 133.8
# episode 455 of 1000 complete,  explore val = 0.01, episode reward = 141.0, ave reward = 133.9
# episode 456 of 1000 complete,  explore val = 0.01, episode reward = 146.0, ave reward = 133.0
# episode 457 of 1000 complete,  explore val = 0.01, episode reward = 145.0, ave reward = 133.2
# episode 458 of 1000 complete,  explore val = 0.01, episode reward = 150.0, ave reward = 133.4
# episode 459 of 1000 complete,  explore val = 0.01, episode reward = 124.0, ave reward = 133.7
# episode 460 of 1000 complete,  explore val = 0.01, episode reward = 165.0, ave reward = 133.9
# episode 461 of 1000 complete,  explore val = 0.01, episode reward = 130.0, ave reward = 134.5
# episode 462 of 1000 complete,  explore val = 0.01, episode reward = 166.0, ave reward = 134.8
# episode 463 of 1000 complete,  explore val = 0.01, episode reward = 143.0, ave reward = 135.2
# episode 464 of 1000 complete,  explore val = 0.01, episode reward = 168.0, ave reward = 135.6
# episode 465 of 1000 complete,  explore val = 0.01, episode reward = 144.0, ave reward = 136.1
# episode 466 of 1000 complete,  explore val = 0.01, episode reward = 128.0, ave reward = 136.6
# episode 467 of 1000 complete,  explore val = 0.01, episode reward = 158.0, ave reward = 136.8
# episode 468 of 1000 complete,  explore val = 0.01, episode reward = 142.0, ave reward = 137.2
# episode 469 of 1000 complete,  explore val = 0.01, episode reward = 162.0, ave reward = 137.5
# episode 470 of 1000 complete,  explore val = 0.01, episode reward = 169.0, ave reward = 138.0
# episode 471 of 1000 complete,  explore val = 0.01, episode reward = 213.0, ave reward = 138.6
# episode 472 of 1000 complete,  explore val = 0.01, episode reward = 149.0, ave reward = 139.7
# episode 473 of 1000 complete,  explore val = 0.01, episode reward = 260.0, ave reward = 141.0
# episode 474 of 1000 complete,  explore val = 0.01, episode reward = 131.0, ave reward = 143.0
# episode 475 of 1000 complete,  explore val = 0.01, episode reward = 218.0, ave reward = 143.5
# episode 476 of 1000 complete,  explore val = 0.01, episode reward = 184.0, ave reward = 144.4
# episode 477 of 1000 complete,  explore val = 0.01, episode reward = 259.0, ave reward = 144.9
# episode 478 of 1000 complete,  explore val = 0.01, episode reward = 190.0, ave reward = 146.6
# episode 479 of 1000 complete,  explore val = 0.01, episode reward = 204.0, ave reward = 147.4
# episode 480 of 1000 complete,  explore val = 0.01, episode reward = 142.0, ave reward = 149.0
# episode 481 of 1000 complete,  explore val = 0.01, episode reward = 65.0, ave reward = 149.9
# episode 482 of 1000 complete,  explore val = 0.01, episode reward = 96.0, ave reward = 150.0
# episode 483 of 1000 complete,  explore val = 0.01, episode reward = 52.0, ave reward = 150.0
# episode 484 of 1000 complete,  explore val = 0.01, episode reward = 53.0, ave reward = 149.1
# episode 485 of 1000 complete,  explore val = 0.01, episode reward = 57.0, ave reward = 148.1
# episode 486 of 1000 complete,  explore val = 0.01, episode reward = 16.0, ave reward = 147.6
# episode 487 of 1000 complete,  explore val = 0.01, episode reward = 136.0, ave reward = 146.8
# episode 488 of 1000 complete,  explore val = 0.01, episode reward = 24.0, ave reward = 146.6
# episode 489 of 1000 complete,  explore val = 0.01, episode reward = 121.0, ave reward = 145.4
# episode 490 of 1000 complete,  explore val = 0.01, episode reward = 96.0, ave reward = 145.2
# episode 491 of 1000 complete,  explore val = 0.01, episode reward = 108.0, ave reward = 144.7
# episode 492 of 1000 complete,  explore val = 0.01, episode reward = 99.0, ave reward = 144.3
# episode 493 of 1000 complete,  explore val = 0.01, episode reward = 85.0, ave reward = 143.9
# episode 494 of 1000 complete,  explore val = 0.01, episode reward = 113.0, ave reward = 143.3
# episode 495 of 1000 complete,  explore val = 0.01, episode reward = 102.0, ave reward = 143.0
# episode 496 of 1000 complete,  explore val = 0.01, episode reward = 103.0, ave reward = 142.6
# episode 497 of 1000 complete,  explore val = 0.01, episode reward = 118.0, ave reward = 142.2
# episode 498 of 1000 complete,  explore val = 0.01, episode reward = 126.0, ave reward = 141.8
# episode 499 of 1000 complete,  explore val = 0.01, episode reward = 106.0, ave reward = 141.4
# episode 500 of 1000 complete,  explore val = 0.01, episode reward = 84.0, ave reward = 141.0
# episode 501 of 1000 complete,  explore val = 0.01, episode reward = 111.0, ave reward = 140.1
# episode 502 of 1000 complete,  explore val = 0.01, episode reward = 107.0, ave reward = 139.4
# episode 503 of 1000 complete,  explore val = 0.01, episode reward = 85.0, ave reward = 137.7
# episode 504 of 1000 complete,  explore val = 0.01, episode reward = 87.0, ave reward = 137.2
# episode 505 of 1000 complete,  explore val = 0.01, episode reward = 111.0, ave reward = 136.2
# episode 506 of 1000 complete,  explore val = 0.01, episode reward = 132.0, ave reward = 134.8
# episode 507 of 1000 complete,  explore val = 0.01, episode reward = 116.0, ave reward = 133.6
# episode 508 of 1000 complete,  explore val = 0.01, episode reward = 105.0, ave reward = 132.6
# episode 509 of 1000 complete,  explore val = 0.01, episode reward = 122.0, ave reward = 132.2
# episode 510 of 1000 complete,  explore val = 0.01, episode reward = 119.0, ave reward = 133.2
# episode 511 of 1000 complete,  explore val = 0.01, episode reward = 111.0, ave reward = 132.9
# episode 512 of 1000 complete,  explore val = 0.01, episode reward = 114.0, ave reward = 132.1
# episode 513 of 1000 complete,  explore val = 0.01, episode reward = 118.0, ave reward = 130.0
# episode 514 of 1000 complete,  explore val = 0.01, episode reward = 105.0, ave reward = 128.2
# episode 515 of 1000 complete,  explore val = 0.01, episode reward = 102.0, ave reward = 127.0
# episode 516 of 1000 complete,  explore val = 0.01, episode reward = 124.0, ave reward = 125.0
# episode 517 of 1000 complete,  explore val = 0.01, episode reward = 107.0, ave reward = 125.0
# episode 518 of 1000 complete,  explore val = 0.01, episode reward = 121.0, ave reward = 125.5
# episode 519 of 1000 complete,  explore val = 0.01, episode reward = 106.0, ave reward = 126.4
# episode 520 of 1000 complete,  explore val = 0.01, episode reward = 144.0, ave reward = 126.6
# episode 521 of 1000 complete,  explore val = 0.01, episode reward = 116.0, ave reward = 127.0
# episode 522 of 1000 complete,  explore val = 0.01, episode reward = 123.0, ave reward = 127.5
# episode 523 of 1000 complete,  explore val = 0.01, episode reward = 137.0, ave reward = 127.9
# episode 524 of 1000 complete,  explore val = 0.01, episode reward = 118.0, ave reward = 127.7
# episode 525 of 1000 complete,  explore val = 0.01, episode reward = 127.0, ave reward = 127.3
# episode 526 of 1000 complete,  explore val = 0.01, episode reward = 128.0, ave reward = 127.1
# episode 527 of 1000 complete,  explore val = 0.01, episode reward = 122.0, ave reward = 126.8
# episode 528 of 1000 complete,  explore val = 0.01, episode reward = 136.0, ave reward = 126.8
# episode 529 of 1000 complete,  explore val = 0.01, episode reward = 116.0, ave reward = 127.0
# episode 530 of 1000 complete,  explore val = 0.01, episode reward = 133.0, ave reward = 126.4
# episode 531 of 1000 complete,  explore val = 0.01, episode reward = 111.0, ave reward = 126.3
# episode 532 of 1000 complete,  explore val = 0.01, episode reward = 166.0, ave reward = 125.9
# episode 533 of 1000 complete,  explore val = 0.01, episode reward = 131.0, ave reward = 126.2
# episode 534 of 1000 complete,  explore val = 0.01, episode reward = 128.0, ave reward = 125.6
# episode 535 of 1000 complete,  explore val = 0.01, episode reward = 125.0, ave reward = 125.6
# episode 536 of 1000 complete,  explore val = 0.01, episode reward = 128.0, ave reward = 125.4
# episode 537 of 1000 complete,  explore val = 0.01, episode reward = 133.0, ave reward = 125.5
# episode 538 of 1000 complete,  explore val = 0.01, episode reward = 127.0, ave reward = 125.2
# episode 539 of 1000 complete,  explore val = 0.01, episode reward = 119.0, ave reward = 125.1
# episode 540 of 1000 complete,  explore val = 0.01, episode reward = 113.0, ave reward = 125.2
# episode 541 of 1000 complete,  explore val = 0.01, episode reward = 149.0, ave reward = 125.1
# episode 542 of 1000 complete,  explore val = 0.01, episode reward = 114.0, ave reward = 125.4
# episode 543 of 1000 complete,  explore val = 0.01, episode reward = 126.0, ave reward = 125.4
# episode 544 of 1000 complete,  explore val = 0.01, episode reward = 122.0, ave reward = 125.5
# episode 545 of 1000 complete,  explore val = 0.01, episode reward = 133.0, ave reward = 125.4
# episode 546 of 1000 complete,  explore val = 0.01, episode reward = 137.0, ave reward = 125.6
# episode 547 of 1000 complete,  explore val = 0.01, episode reward = 123.0, ave reward = 125.8
# episode 548 of 1000 complete,  explore val = 0.01, episode reward = 156.0, ave reward = 125.9
# episode 549 of 1000 complete,  explore val = 0.01, episode reward = 121.0, ave reward = 126.0
# episode 550 of 1000 complete,  explore val = 0.01, episode reward = 160.0, ave reward = 127.0
# episode 551 of 1000 complete,  explore val = 0.01, episode reward = 118.0, ave reward = 127.6
# episode 552 of 1000 complete,  explore val = 0.01, episode reward = 154.0, ave reward = 127.4
# episode 553 of 1000 complete,  explore val = 0.01, episode reward = 132.0, ave reward = 127.4
# episode 554 of 1000 complete,  explore val = 0.01, episode reward = 145.0, ave reward = 127.5
# episode 555 of 1000 complete,  explore val = 0.01, episode reward = 142.0, ave reward = 127.6
# episode 556 of 1000 complete,  explore val = 0.01, episode reward = 128.0, ave reward = 127.7
# episode 557 of 1000 complete,  explore val = 0.01, episode reward = 165.0, ave reward = 127.5
# episode 558 of 1000 complete,  explore val = 0.01, episode reward = 135.0, ave reward = 127.7
# episode 559 of 1000 complete,  explore val = 0.01, episode reward = 209.0, ave reward = 127.5
# episode 560 of 1000 complete,  explore val = 0.01, episode reward = 128.0, ave reward = 128.4
# episode 561 of 1000 complete,  explore val = 0.01, episode reward = 164.0, ave reward = 128.0
# episode 562 of 1000 complete,  explore val = 0.01, episode reward = 142.0, ave reward = 128.4
# episode 563 of 1000 complete,  explore val = 0.01, episode reward = 154.0, ave reward = 128.1
# episode 564 of 1000 complete,  explore val = 0.01, episode reward = 165.0, ave reward = 128.2
# episode 565 of 1000 complete,  explore val = 0.01, episode reward = 17.0, ave reward = 128.2
# episode 566 of 1000 complete,  explore val = 0.01, episode reward = 16.0, ave reward = 126.9
# episode 567 of 1000 complete,  explore val = 0.01, episode reward = 178.0, ave reward = 125.8
# episode 568 of 1000 complete,  explore val = 0.01, episode reward = 215.0, ave reward = 126.0
# episode 569 of 1000 complete,  explore val = 0.01, episode reward = 235.0, ave reward = 126.7
# episode 570 of 1000 complete,  explore val = 0.01, episode reward = 171.0, ave reward = 127.5
# episode 571 of 1000 complete,  explore val = 0.01, episode reward = 273.0, ave reward = 127.5
# episode 572 of 1000 complete,  explore val = 0.01, episode reward = 171.0, ave reward = 128.1
# episode 573 of 1000 complete,  explore val = 0.01, episode reward = 237.0, ave reward = 128.3
# episode 574 of 1000 complete,  explore val = 0.01, episode reward = 201.0, ave reward = 128.1
# episode 575 of 1000 complete,  explore val = 0.01, episode reward = 173.0, ave reward = 128.8
# episode 576 of 1000 complete,  explore val = 0.01, episode reward = 182.0, ave reward = 128.3
# episode 577 of 1000 complete,  explore val = 0.01, episode reward = 226.0, ave reward = 128.3
# episode 578 of 1000 complete,  explore val = 0.01, episode reward = 215.0, ave reward = 128.0
# episode 579 of 1000 complete,  explore val = 0.01, episode reward = 200.0, ave reward = 128.2
# episode 580 of 1000 complete,  explore val = 0.01, episode reward = 259.0, ave reward = 128.2
# episode 581 of 1000 complete,  explore val = 0.01, episode reward = 192.0, ave reward = 129.4
# episode 582 of 1000 complete,  explore val = 0.01, episode reward = 251.0, ave reward = 130.6
# episode 583 of 1000 complete,  explore val = 0.01, episode reward = 187.0, ave reward = 132.2
# episode 584 of 1000 complete,  explore val = 0.01, episode reward = 189.0, ave reward = 133.5
# episode 585 of 1000 complete,  explore val = 0.01, episode reward = 243.0, ave reward = 134.9
# episode 586 of 1000 complete,  explore val = 0.01, episode reward = 216.0, ave reward = 136.7
# episode 587 of 1000 complete,  explore val = 0.01, episode reward = 195.0, ave reward = 138.7
# episode 588 of 1000 complete,  explore val = 0.01, episode reward = 224.0, ave reward = 139.3
# episode 589 of 1000 complete,  explore val = 0.01, episode reward = 232.0, ave reward = 141.3
# episode 590 of 1000 complete,  explore val = 0.01, episode reward = 210.0, ave reward = 142.4
# episode 591 of 1000 complete,  explore val = 0.01, episode reward = 241.0, ave reward = 143.6
# episode 592 of 1000 complete,  explore val = 0.01, episode reward = 233.0, ave reward = 144.9
# episode 593 of 1000 complete,  explore val = 0.01, episode reward = 227.0, ave reward = 146.2
# episode 594 of 1000 complete,  explore val = 0.01, episode reward = 241.0, ave reward = 147.7
# episode 595 of 1000 complete,  explore val = 0.01, episode reward = 257.0, ave reward = 149.0
# episode 596 of 1000 complete,  explore val = 0.01, episode reward = 250.0, ave reward = 150.5
# episode 597 of 1000 complete,  explore val = 0.01, episode reward = 325.0, ave reward = 152.0
# episode 598 of 1000 complete,  explore val = 0.01, episode reward = 240.0, ave reward = 154.0
# episode 599 of 1000 complete,  explore val = 0.01, episode reward = 409.0, ave reward = 155.2
# episode 600 of 1000 complete,  explore val = 0.01, episode reward = 222.0, ave reward = 158.2
# episode 601 of 1000 complete,  explore val = 0.01, episode reward = 484.0, ave reward = 159.6
# episode 602 of 1000 complete,  explore val = 0.01, episode reward = 276.0, ave reward = 163.3
# episode 603 of 1000 complete,  explore val = 0.01, episode reward = 500.0, ave reward = 165.0
# episode 604 of 1000 complete,  explore val = 0.01, episode reward = 405.0, ave reward = 169.2
# episode 605 of 1000 complete,  explore val = 0.01, episode reward = 218.0, ave reward = 172.3
# episode 606 of 1000 complete,  explore val = 0.01, episode reward = 8.0, ave reward = 173.4
# episode 607 of 1000 complete,  explore val = 0.01, episode reward = 9.0, ave reward = 172.2
# episode 608 of 1000 complete,  explore val = 0.01, episode reward = 82.0, ave reward = 171.1
# episode 609 of 1000 complete,  explore val = 0.01, episode reward = 100.0, ave reward = 170.9
# episode 610 of 1000 complete,  explore val = 0.01, episode reward = 133.0, ave reward = 170.6
# episode 611 of 1000 complete,  explore val = 0.01, episode reward = 493.0, ave reward = 170.8
# episode 612 of 1000 complete,  explore val = 0.01, episode reward = 316.0, ave reward = 174.6
# episode 613 of 1000 complete,  explore val = 0.01, episode reward = 204.0, ave reward = 176.6
# episode 614 of 1000 complete,  explore val = 0.01, episode reward = 175.0, ave reward = 177.5
# episode 615 of 1000 complete,  explore val = 0.01, episode reward = 125.0, ave reward = 178.2
# episode 616 of 1000 complete,  explore val = 0.01, episode reward = 138.0, ave reward = 178.4
# episode 617 of 1000 complete,  explore val = 0.01, episode reward = 187.0, ave reward = 178.6
# episode 618 of 1000 complete,  explore val = 0.01, episode reward = 200.0, ave reward = 179.4
# episode 619 of 1000 complete,  explore val = 0.01, episode reward = 205.0, ave reward = 180.2
# episode 620 of 1000 complete,  explore val = 0.01, episode reward = 197.0, ave reward = 181.1
# episode 621 of 1000 complete,  explore val = 0.01, episode reward = 201.0, ave reward = 181.7
# episode 622 of 1000 complete,  explore val = 0.01, episode reward = 197.0, ave reward = 182.5
# episode 623 of 1000 complete,  explore val = 0.01, episode reward = 177.0, ave reward = 183.3
# episode 624 of 1000 complete,  explore val = 0.01, episode reward = 172.0, ave reward = 183.7
# episode 625 of 1000 complete,  explore val = 0.01, episode reward = 218.0, ave reward = 184.2
# episode 626 of 1000 complete,  explore val = 0.01, episode reward = 184.0, ave reward = 185.1
# episode 627 of 1000 complete,  explore val = 0.01, episode reward = 219.0, ave reward = 185.7
# episode 628 of 1000 complete,  explore val = 0.01, episode reward = 205.0, ave reward = 186.6
# episode 629 of 1000 complete,  explore val = 0.01, episode reward = 205.0, ave reward = 187.3
# episode 630 of 1000 complete,  explore val = 0.01, episode reward = 192.0, ave reward = 188.2
# episode 631 of 1000 complete,  explore val = 0.01, episode reward = 235.0, ave reward = 188.8
# episode 632 of 1000 complete,  explore val = 0.01, episode reward = 196.0, ave reward = 190.0
# episode 633 of 1000 complete,  explore val = 0.01, episode reward = 202.0, ave reward = 190.4
# episode 634 of 1000 complete,  explore val = 0.01, episode reward = 221.0, ave reward = 191.1
# episode 635 of 1000 complete,  explore val = 0.01, episode reward = 200.0, ave reward = 192.0
# episode 636 of 1000 complete,  explore val = 0.01, episode reward = 207.0, ave reward = 192.7
# episode 637 of 1000 complete,  explore val = 0.01, episode reward = 170.0, ave reward = 193.5
# episode 638 of 1000 complete,  explore val = 0.01, episode reward = 185.0, ave reward = 193.9
# episode 639 of 1000 complete,  explore val = 0.01, episode reward = 141.0, ave reward = 194.5
# episode 640 of 1000 complete,  explore val = 0.01, episode reward = 215.0, ave reward = 194.7
# episode 641 of 1000 complete,  explore val = 0.01, episode reward = 227.0, ave reward = 195.7
# episode 642 of 1000 complete,  explore val = 0.01, episode reward = 158.0, ave reward = 196.5
# episode 643 of 1000 complete,  explore val = 0.01, episode reward = 218.0, ave reward = 196.9
# episode 644 of 1000 complete,  explore val = 0.01, episode reward = 185.0, ave reward = 197.9
# episode 645 of 1000 complete,  explore val = 0.01, episode reward = 206.0, ave reward = 198.5
# episode 646 of 1000 complete,  explore val = 0.01, episode reward = 158.0, ave reward = 199.2
# episode 647 of 1000 complete,  explore val = 0.01, episode reward = 162.0, ave reward = 199.4
# episode 648 of 1000 complete,  explore val = 0.01, episode reward = 118.0, ave reward = 199.8
# episode 649 of 1000 complete,  explore val = 0.01, episode reward = 170.0, ave reward = 199.4
# episode 650 of 1000 complete,  explore val = 0.01, episode reward = 140.0, ave reward = 199.9
# episode 651 of 1000 complete,  explore val = 0.01, episode reward = 218.0, ave reward = 199.7
# episode 652 of 1000 complete,  explore val = 0.01, episode reward = 154.0, ave reward = 200.7
# q-learning algorithm complete

# %% [markdown]
# # Plot total episode reward history

# %%
reward_logname = 'reward_logs/' + savename + '.txt'
plot_reward_history(reward_logname,window_length = exit_window)
