# %% [markdown]
# # Fitted Q-learning algo

# %% [markdown]
# Below is a version of the fitted Q-Learning algorithm described [last time]((https://www.dropbox.com/s/3qjqhpo1mix0w9h/deep_QLearning_part_2_SLIDES.pdf?dl=0).  Recall the main variation here is just this: instead of updating $Q$ *inside* each episode, we wait (at least) until the end of the episode to update.
#
# A few quirks of this implementation:
# - its written in Python-Autograd
# - The size of memory for memory replay is fixed at a number of episodes instead of a number of steps.
# - There are a large number of user-controls - defined in the initialization - that allow for a wide range of use, including parameters to control how often the weights of $Q$ are saved, how often $Q$ is updated (in terms of number of episodes),...

# %%
from autograd import numpy as np
import copy
import os
import pickle
import sys
import gym

# shared architecture builder written in python-autograd
import python_autograd_arch_designer as funclib

class QLearner():
    # load in simulator, initialize global variables
    def __init__(self,gymname,dirname,savename,**kwargs):
        # load in gym simulator
        self.simulator = gym.make(gymname) 
             
        # Q learn basic params
        self.explore_val = 1       # how often should an action be chosen randomly vs using the optimal control law, larger values mean actions are more often chosen randomly
        self.explore_decay = 0.99  # after each episode the explore_val is multiplied by explore_decay to (potentially) shrink it
        self.gamma = 1             # short-term/long-term trade-off param
        self.num_episodes = 500    # number of episodes of simulation to perform
        self.save_weight_freq = 10 # controls how often (in number of episodes) the weights of $Q$ are saved 
        self.memory = []           # memory container
        
        # fitted Q-Learning params
        self.episode_update = 1     # after how many episodes should we update Q?
        self.memory_length = 10     # length of memory replay (in episodes)

        # simulation-specific params
        self.exit_level = 200       # sets the optimal episode reward required for 'success'
        self.exit_window = 100      # sets the window over which average total reward per episode must be >= exit_level  to deem Q resolved successfully
        
        # let user define each of the params above
        if "gamma" in kwargs:   
            self.gamma = args['gamma']
        if 'explore_val' in kwargs:
            self.explore_val = kwargs['explore_val']
        if 'explore_decay' in kwargs:
            self.explore_decay = kwargs['explore_decay']
        if 'num_episodes' in kwargs:
            self.num_episodes = kwargs['num_episodes']
        if 'episode_update' in kwargs:
            self.episode_update = kwargs['episode_update']
        if 'exit_level' in kwargs:
            self.exit_level = kwargs['exit_level']
        if 'exit_window' in kwargs:
            self.exit_window = kwargs['exit_window']  
        if 'save_weight_freq' in kwargs:
            self.save_weight_freq = kwargs['save_weight_freq']
        if 'memory_length' in kwargs:
            self.memory_length = kwargs['memory_length']
        if 'episode_update' in kwargs:
            self.episode_update = kwargs['episode_update']
            
        # get simulation-specific variables from simulator
        self.num_actions = self.simulator.action_space.n
        state = self.simulator.reset()    
        self.state_dim = np.size(state)
        self.training_reward = []
            
        ### initialize logs ###
        # create text file for training log
        self.logname = dirname + '/training_logs/' + savename + '.txt'
        self.reward_logname =  dirname + '/reward_logs/' + savename + '.txt'
        self.weight_name =  dirname + '/saved_model_weights/' + savename + '.pkl' 
        self.model_name =  dirname + '/models/' + savename + '.json'

        self.init_log(self.logname)
        self.init_log(self.reward_logname)
        self.init_log(self.weight_name)
        self.init_log(self.model_name)
     
    ##### logging functions #####
    def init_log(self,logname):
        # delete log if old version exists
        if os.path.exists(logname): 
            os.remove(logname)
            
    def update_log(self,logname,update):
        if type(update) == str:
            logfile = open(logname, "a")
            logfile.write(update)
            logfile.close() 
        else:
            weights = []
            if os.path.exists(logname):
                with open(logname,'rb') as rfp: 
                    weights = pickle.load(rfp)
            weights.append(update)

            with open(logname,'wb') as wfp:
                pickle.dump(weights, wfp)
    
    ##### functions for creating / updating Q #####
    def initialize_Q(self,**kwargs):
        # default parameters for network
        layer_sizes = [10,10]      # two hidden layers, 10 units each, by default
        activation = 'relu'
        if 'layer_sizes' in kwargs:
            layer_sizes = kwargs['layer_sizes']
        if 'activation' in kwargs:
            activation = kwargs['activation']

        # default parameters for optimizer - reset by hand
        loss = 'mse'
        self.lr = 10**(-2)
        if 'alpha' in kwargs:
            self.lr = kwargs['alpha']

        # input / output sizes of network
        input_dim = self.state_dim
        output_dim = self.num_actions
    
        # setup network
        layer_sizes.insert(0,input_dim)
        layer_sizes.append(output_dim)

        # setup architecture, choose cost, and setup architecture
        self.model = funclib.super_setup.Setup()
        self.model.choose_cost(name = 'least_squares')
        self.model.choose_features(layer_sizes = layer_sizes,activation = activation)
            
        # initialize Q
        self.Q = self.model.predict

    # update Q function
    def update_Q(self):
        # generate q_values based on most recent Q
        q_vals = []
        states = []
        for i in range(len(self.memory)):    
            # get episode_data
            episode_data = self.memory[i]
            
            # loop over episode data and create input/output pairs
            for j in range(len(episode_data)):
                # get next sample of episode
                sample = episode_data[j]
            
                # strip sample for parts
                state = sample[0]
                next_state = sample[1]
                action = sample[2]
                reward = sample[3]
                done = sample[4]

                ### for cartpole only - check if done, and alter reward to improve learning ###
                done,reward = self.check_done(done,reward)

                # compute and store q value
                q = reward 
                if done == False:
                    qs = self.Q(next_state.T)
                    q += self.gamma*np.max(qs)

                # clamp all other models to their current values for this input/output pair
                q_update = self.Q(state.T).flatten()
                q_update[action] = q
                q_vals.append(q_update)
                states.append(state.T)
            
        # convert lists to numpy arrays for regressor
        s_in = np.array(states).T
        q_vals = np.array(q_vals).T
        s_in = s_in[0,:,:]
                            
        # take descent step
        self.model.fit(s_in,q_vals,algo = 'RMSprop',max_its = 1,alpha = self.lr,verbose = False)
        
        # update Q based on regressor updates
        self.Q = self.model.predict
        
    ##### functions for adjusting replay memory #####
    # update memory - add sample to list, remove oldest samples 
    def update_memory(self,episode_data):
        # add most recent trial data to memory
        self.memory.append(episode_data)

        # clip memory if it gets too long    
        num_episodes = len(self.memory)
        if num_episodes >= self.memory_length:    
            num_delete = num_episodes - self.memory_length
            self.memory[:num_delete] = []
    
    ##### Q Learning functionality #####
    # state normalizer
    def state_normalizer(self,states):
        states = np.array(states)[np.newaxis,:]
        return states
    
    # choose next action
    def choose_action(self,state):
        # pick action at random
        p = np.random.rand(1)   
        action = np.random.randint(self.num_actions)
            
        # pick action based on exploiting
        qs = self.Q(state.T) 
        if p > self.explore_val:
            action = np.argmax(qs)
        return action

    # special function to check done
    def check_done(self,done,reward):
        if done == True:
            reward = -100
        return done,reward
    
    # main training function
    def train(self,**kwargs):        
            
        ### start main Q-learning loop ###
        for n in range(self.num_episodes): 
            # pick this episode's starting position - randomly initialize from f_system
            state = self.simulator.reset()    
            state = self.state_normalizer(state)
            total_episode_reward = 0
            done = False
            
            # get out exploit parameter for this episode
            if self.explore_val > 0.01:
                self.explore_val *= self.explore_decay
                    
            # run episode
            step = 0
            episode_data = []
            while done == False and step < 500:    
                # choose next action
                action = self.choose_action(state)
    
                # transition to next state, get associated reward
                next_state,reward,done,info = self.simulator.step(action)  
                next_state = self.state_normalizer(next_state)
                
                # store data for transition after episode ends
                episode_data.append([state,next_state,action,reward,done])

                # update total reward from this episode
                total_episode_reward+=reward
                state = copy.deepcopy(next_state)
                step+=1
                
            # store this episode's computation time and training reward history
            self.training_reward.append(total_episode_reward)
                
            # update memory with this episode's data
            self.update_memory(episode_data)
            
            # update Q function
            if np.mod(n,self.episode_update) == 0:
                self.update_Q()  
                  
            # update episode reward greater than exit_level, add to counter
            exit_ave = total_episode_reward
            if n >= self.exit_window:
                exit_ave = np.sum(np.array(self.training_reward[-self.exit_window:]))/self.exit_window

            ### print out updates ###
            update = 'episode ' + str(n+1) +  ' of ' + str(self.num_episodes) + ' complete, ' +  ' explore val = ' + str(np.round(self.explore_val,3)) + ', episode reward = ' + str(np.round(total_episode_reward,1)) + ', ave reward = ' + str(np.round(exit_ave,1))
            self.update_log(self.logname,update + '\n')
                              
            # print out updates 
            print (update)
            
            # record rewards
            update = str(total_episode_reward) + '\n'
            self.update_log(self.reward_logname,update)
            
            # save latest weights from this episode 
            if np.mod(n,self.save_weight_freq) == 0:
                update = self.model.weight_history[-1]
                self.update_log(self.weight_name,update)
            
            # if the total episode reward is greater than exit level for 10 consecutive episodes, break
            if exit_ave >= self.exit_level and n >= self.exit_window:
                break
            
        ### save weights ###
        update = 'q-learning algorithm complete'
        self.update_log(self.logname,update + '\n')
        print (update)

# %% [markdown]
# # Episode reward history plotter

# %%
import matplotlib.pyplot as plt
import numpy as np

# moving average function
def moving_average(x,D):
    y = []
    for p in range(len(x)+1):
        # make next element
        b = np.sum(x[np.maximum(0,p-D):p])/float(D)
        y.append(b)
    return np.array(y)

def plot_reward_history(logname,**kwargs):
    start = 1
    window_length = 5
    if 'window_length' in kwargs:
        window_length = kwargs['window_length']
    if 'start' in kwargs:
        start = kwargs['start']
        
    # load in total episode reward history
    data = np.loadtxt(logname)
    ave = moving_average(data,window_length)

    # create figure
    fig = plt.figure(figsize = (12,8))
    ax1 = fig.add_subplot(2,1,1)
    ax2 = fig.add_subplot(2,1,2)

    # plot total reward history
    ax1.plot(data)
    ax1.set_xlabel('episode',labelpad = 8,fontsize = 13)
    ax1.set_ylabel('total reward',fontsize = 13)
    
    ave[:window_length] = np.nan
    ax2.plot(ave,linewidth=3)
    ax2.set_xlabel('episode',labelpad = 8,fontsize = 13)
    ax2.set_ylabel('ave total reward',fontsize=13)
    plt.show()

# %% [markdown]
# # Run fitted Q-Learning algo

# %%
# feed in current directory name and savename = experiment name
dirname = os.getcwd()
savename = 'qfitted_cartpole_experiment_1'
gymname = 'CartPole-v1'

# initialize Q Learn process
num_episodes = 1000
explore_decay = 1
explore_val = 0.01
exit_level = 200
exit_window = 100
save_weight_freq = 1000

# initialize memory
episode_update = 1
memory_length = 1

# load into instance of learner
demo = QLearner(gymname,dirname,savename,num_episodes=num_episodes,explore_decay=explore_decay,explore_val=explore_val,memory_length=memory_length,episode_update=episode_update,exit_level=exit_level,exit_window=exit_window,save_weight_freq=save_weight_freq)

# initialize Q function
layer_sizes = [50,50]
alpha = 10**(-2)
activation = 'relu'
demo.initialize_Q(layer_sizes=layer_sizes,alpha=alpha,activation=activation)
# Out:
# WARN: gym.spaces.Box autodetected dtype as <class 'numpy.float32'>. Please provide explicit dtype.

# %%
demo.train()
# Out:
# episode 1 of 1000 complete,  explore val = 0.01, episode reward = 10.0, ave reward = 10.0
# episode 2 of 1000 complete,  explore val = 0.01, episode reward = 16.0, ave reward = 16.0
# episode 3 of 1000 complete,  explore val = 0.01, episode reward = 9.0, ave reward = 9.0
# episode 4 of 1000 complete,  explore val = 0.01, episode reward = 38.0, ave reward = 38.0
# episode 5 of 1000 complete,  explore val = 0.01, episode reward = 11.0, ave reward = 11.0
# episode 6 of 1000 complete,  explore val = 0.01, episode reward = 9.0, ave reward = 9.0
# episode 7 of 1000 complete,  explore val = 0.01, episode reward = 9.0, ave reward = 9.0
# episode 8 of 1000 complete,  explore val = 0.01, episode reward = 9.0, ave reward = 9.0
# episode 9 of 1000 complete,  explore val = 0.01, episode reward = 10.0, ave reward = 10.0
# episode 10 of 1000 complete,  explore val = 0.01, episode reward = 61.0, ave reward = 61.0
# episode 11 of 1000 complete,  explore val = 0.01, episode reward = 35.0, ave reward = 35.0
# episode 12 of 1000 complete,  explore val = 0.01, episode reward = 15.0, ave reward = 15.0
# episode 13 of 1000 complete,  explore val = 0.01, episode reward = 9.0, ave reward = 9.0
# episode 14 of 1000 complete,  explore val = 0.01, episode reward = 25.0, ave reward = 25.0
# episode 15 of 1000 complete,  explore val = 0.01, episode reward = 49.0, ave reward = 49.0
# episode 16 of 1000 complete,  explore val = 0.01, episode reward = 22.0, ave reward = 22.0
# episode 17 of 1000 complete,  explore val = 0.01, episode reward = 10.0, ave reward = 10.0
# episode 18 of 1000 complete,  explore val = 0.01, episode reward = 10.0, ave reward = 10.0
# episode 19 of 1000 complete,  explore val = 0.01, episode reward = 9.0, ave reward = 9.0
# episode 20 of 1000 complete,  explore val = 0.01, episode reward = 50.0, ave reward = 50.0
# episode 21 of 1000 complete,  explore val = 0.01, episode reward = 25.0, ave reward = 25.0
# episode 22 of 1000 complete,  explore val = 0.01, episode reward = 12.0, ave reward = 12.0
# episode 23 of 1000 complete,  explore val = 0.01, episode reward = 34.0, ave reward = 34.0
# episode 24 of 1000 complete,  explore val = 0.01, episode reward = 17.0, ave reward = 17.0
# episode 25 of 1000 complete,  explore val = 0.01, episode reward = 9.0, ave reward = 9.0
# episode 26 of 1000 complete,  explore val = 0.01, episode reward = 21.0, ave reward = 21.0
# episode 27 of 1000 complete,  explore val = 0.01, episode reward = 72.0, ave reward = 72.0
# episode 28 of 1000 complete,  explore val = 0.01, episode reward = 36.0, ave reward = 36.0
# episode 29 of 1000 complete,  explore val = 0.01, episode reward = 23.0, ave reward = 23.0
# episode 30 of 1000 complete,  explore val = 0.01, episode reward = 13.0, ave reward = 13.0
# episode 31 of 1000 complete,  explore val = 0.01, episode reward = 66.0, ave reward = 66.0
# episode 32 of 1000 complete,  explore val = 0.01, episode reward = 23.0, ave reward = 23.0
# episode 33 of 1000 complete,  explore val = 0.01, episode reward = 42.0, ave reward = 42.0
# episode 34 of 1000 complete,  explore val = 0.01, episode reward = 19.0, ave reward = 19.0
# episode 35 of 1000 complete,  explore val = 0.01, episode reward = 8.0, ave reward = 8.0
# episode 36 of 1000 complete,  explore val = 0.01, episode reward = 32.0, ave reward = 32.0
# episode 37 of 1000 complete,  explore val = 0.01, episode reward = 20.0, ave reward = 20.0
# episode 38 of 1000 complete,  explore val = 0.01, episode reward = 97.0, ave reward = 97.0
# episode 39 of 1000 complete,  explore val = 0.01, episode reward = 28.0, ave reward = 28.0
# episode 40 of 1000 complete,  explore val = 0.01, episode reward = 11.0, ave reward = 11.0
# episode 41 of 1000 complete,  explore val = 0.01, episode reward = 10.0, ave reward = 10.0
# episode 42 of 1000 complete,  explore val = 0.01, episode reward = 10.0, ave reward = 10.0
# episode 43 of 1000 complete,  explore val = 0.01, episode reward = 34.0, ave reward = 34.0
# episode 44 of 1000 complete,  explore val = 0.01, episode reward = 10.0, ave reward = 10.0
# episode 45 of 1000 complete,  explore val = 0.01, episode reward = 11.0, ave reward = 11.0
# episode 46 of 1000 complete,  explore val = 0.01, episode reward = 8.0, ave reward = 8.0
# episode 47 of 1000 complete,  explore val = 0.01, episode reward = 25.0, ave reward = 25.0
# episode 48 of 1000 complete,  explore val = 0.01, episode reward = 9.0, ave reward = 9.0
# episode 49 of 1000 complete,  explore val = 0.01, episode reward = 18.0, ave reward = 18.0
# episode 50 of 1000 complete,  explore val = 0.01, episode reward = 10.0, ave reward = 10.0
# episode 51 of 1000 complete,  explore val = 0.01, episode reward = 16.0, ave reward = 16.0
# episode 52 of 1000 complete,  explore val = 0.01, episode reward = 10.0, ave reward = 10.0
# episode 53 of 1000 complete,  explore val = 0.01, episode reward = 42.0, ave reward = 42.0
# episode 54 of 1000 complete,  explore val = 0.01, episode reward = 9.0, ave reward = 9.0
# episode 55 of 1000 complete,  explore val = 0.01, episode reward = 39.0, ave reward = 39.0
# episode 56 of 1000 complete,  explore val = 0.01, episode reward = 17.0, ave reward = 17.0
# episode 57 of 1000 complete,  explore val = 0.01, episode reward = 16.0, ave reward = 16.0
# episode 58 of 1000 complete,  explore val = 0.01, episode reward = 20.0, ave reward = 20.0
# episode 59 of 1000 complete,  explore val = 0.01, episode reward = 18.0, ave reward = 18.0
# episode 60 of 1000 complete,  explore val = 0.01, episode reward = 25.0, ave reward = 25.0
# episode 61 of 1000 complete,  explore val = 0.01, episode reward = 10.0, ave reward = 10.0
# episode 62 of 1000 complete,  explore val = 0.01, episode reward = 20.0, ave reward = 20.0
# episode 63 of 1000 complete,  explore val = 0.01, episode reward = 33.0, ave reward = 33.0
# episode 64 of 1000 complete,  explore val = 0.01, episode reward = 10.0, ave reward = 10.0
# episode 65 of 1000 complete,  explore val = 0.01, episode reward = 14.0, ave reward = 14.0
# episode 66 of 1000 complete,  explore val = 0.01, episode reward = 15.0, ave reward = 15.0
# episode 67 of 1000 complete,  explore val = 0.01, episode reward = 14.0, ave reward = 14.0
# episode 68 of 1000 complete,  explore val = 0.01, episode reward = 20.0, ave reward = 20.0
# episode 69 of 1000 complete,  explore val = 0.01, episode reward = 10.0, ave reward = 10.0
# episode 70 of 1000 complete,  explore val = 0.01, episode reward = 8.0, ave reward = 8.0
# episode 71 of 1000 complete,  explore val = 0.01, episode reward = 26.0, ave reward = 26.0
# episode 72 of 1000 complete,  explore val = 0.01, episode reward = 25.0, ave reward = 25.0
# episode 73 of 1000 complete,  explore val = 0.01, episode reward = 13.0, ave reward = 13.0
# episode 74 of 1000 complete,  explore val = 0.01, episode reward = 25.0, ave reward = 25.0
# episode 75 of 1000 complete,  explore val = 0.01, episode reward = 48.0, ave reward = 48.0
# episode 76 of 1000 complete,  explore val = 0.01, episode reward = 30.0, ave reward = 30.0
# episode 77 of 1000 complete,  explore val = 0.01, episode reward = 8.0, ave reward = 8.0
# episode 78 of 1000 complete,  explore val = 0.01, episode reward = 39.0, ave reward = 39.0
# episode 79 of 1000 complete,  explore val = 0.01, episode reward = 8.0, ave reward = 8.0
# episode 80 of 1000 complete,  explore val = 0.01, episode reward = 15.0, ave reward = 15.0
# episode 81 of 1000 complete,  explore val = 0.01, episode reward = 31.0, ave reward = 31.0
# episode 82 of 1000 complete,  explore val = 0.01, episode reward = 56.0, ave reward = 56.0
# episode 83 of 1000 complete,  explore val = 0.01, episode reward = 43.0, ave reward = 43.0
# episode 84 of 1000 complete,  explore val = 0.01, episode reward = 16.0, ave reward = 16.0
# episode 85 of 1000 complete,  explore val = 0.01, episode reward = 53.0, ave reward = 53.0
# episode 86 of 1000 complete,  explore val = 0.01, episode reward = 17.0, ave reward = 17.0
# episode 87 of 1000 complete,  explore val = 0.01, episode reward = 28.0, ave reward = 28.0
# episode 88 of 1000 complete,  explore val = 0.01, episode reward = 47.0, ave reward = 47.0
# episode 89 of 1000 complete,  explore val = 0.01, episode reward = 17.0, ave reward = 17.0
# episode 90 of 1000 complete,  explore val = 0.01, episode reward = 32.0, ave reward = 32.0
# episode 91 of 1000 complete,  explore val = 0.01, episode reward = 24.0, ave reward = 24.0
# episode 92 of 1000 complete,  explore val = 0.01, episode reward = 23.0, ave reward = 23.0
# episode 93 of 1000 complete,  explore val = 0.01, episode reward = 27.0, ave reward = 27.0
# episode 94 of 1000 complete,  explore val = 0.01, episode reward = 47.0, ave reward = 47.0
# episode 95 of 1000 complete,  explore val = 0.01, episode reward = 100.0, ave reward = 100.0
# episode 96 of 1000 complete,  explore val = 0.01, episode reward = 103.0, ave reward = 103.0
# episode 97 of 1000 complete,  explore val = 0.01, episode reward = 37.0, ave reward = 37.0
# episode 98 of 1000 complete,  explore val = 0.01, episode reward = 19.0, ave reward = 19.0
# episode 99 of 1000 complete,  explore val = 0.01, episode reward = 26.0, ave reward = 26.0
# episode 100 of 1000 complete,  explore val = 0.01, episode reward = 14.0, ave reward = 14.0
# episode 101 of 1000 complete,  explore val = 0.01, episode reward = 74.0, ave reward = 26.0
# episode 102 of 1000 complete,  explore val = 0.01, episode reward = 22.0, ave reward = 26.0
# episode 103 of 1000 complete,  explore val = 0.01, episode reward = 53.0, ave reward = 26.5
# episode 104 of 1000 complete,  explore val = 0.01, episode reward = 22.0, ave reward = 26.3
# episode 105 of 1000 complete,  explore val = 0.01, episode reward = 28.0, ave reward = 26.5
# episode 106 of 1000 complete,  explore val = 0.01, episode reward = 20.0, ave reward = 26.6
# episode 107 of 1000 complete,  explore val = 0.01, episode reward = 47.0, ave reward = 27.0
# episode 108 of 1000 complete,  explore val = 0.01, episode reward = 116.0, ave reward = 28.0
# episode 109 of 1000 complete,  explore val = 0.01, episode reward = 63.0, ave reward = 28.6
# episode 110 of 1000 complete,  explore val = 0.01, episode reward = 90.0, ave reward = 28.8
# episode 111 of 1000 complete,  explore val = 0.01, episode reward = 23.0, ave reward = 28.7
# episode 112 of 1000 complete,  explore val = 0.01, episode reward = 16.0, ave reward = 28.7
# episode 113 of 1000 complete,  explore val = 0.01, episode reward = 22.0, ave reward = 28.9
# episode 114 of 1000 complete,  explore val = 0.01, episode reward = 57.0, ave reward = 29.2
# episode 115 of 1000 complete,  explore val = 0.01, episode reward = 12.0, ave reward = 28.8
# episode 116 of 1000 complete,  explore val = 0.01, episode reward = 454.0, ave reward = 33.1
# episode 117 of 1000 complete,  explore val = 0.01, episode reward = 27.0, ave reward = 33.3
# episode 118 of 1000 complete,  explore val = 0.01, episode reward = 34.0, ave reward = 33.6
# episode 119 of 1000 complete,  explore val = 0.01, episode reward = 55.0, ave reward = 34.0
# episode 120 of 1000 complete,  explore val = 0.01, episode reward = 24.0, ave reward = 33.8
# episode 121 of 1000 complete,  explore val = 0.01, episode reward = 42.0, ave reward = 33.9
# episode 122 of 1000 complete,  explore val = 0.01, episode reward = 27.0, ave reward = 34.1
# episode 123 of 1000 complete,  explore val = 0.01, episode reward = 26.0, ave reward = 34.0
# episode 124 of 1000 complete,  explore val = 0.01, episode reward = 65.0, ave reward = 34.5
# episode 125 of 1000 complete,  explore val = 0.01, episode reward = 31.0, ave reward = 34.7
# episode 126 of 1000 complete,  explore val = 0.01, episode reward = 25.0, ave reward = 34.7
# episode 127 of 1000 complete,  explore val = 0.01, episode reward = 28.0, ave reward = 34.3
# episode 128 of 1000 complete,  explore val = 0.01, episode reward = 27.0, ave reward = 34.2
# episode 129 of 1000 complete,  explore val = 0.01, episode reward = 19.0, ave reward = 34.2
# episode 130 of 1000 complete,  explore val = 0.01, episode reward = 68.0, ave reward = 34.7
# episode 131 of 1000 complete,  explore val = 0.01, episode reward = 81.0, ave reward = 34.9
# episode 132 of 1000 complete,  explore val = 0.01, episode reward = 34.0, ave reward = 35.0
# episode 133 of 1000 complete,  explore val = 0.01, episode reward = 36.0, ave reward = 34.9
# episode 134 of 1000 complete,  explore val = 0.01, episode reward = 24.0, ave reward = 35.0
# episode 135 of 1000 complete,  explore val = 0.01, episode reward = 76.0, ave reward = 35.6
# episode 136 of 1000 complete,  explore val = 0.01, episode reward = 102.0, ave reward = 36.3
# episode 137 of 1000 complete,  explore val = 0.01, episode reward = 50.0, ave reward = 36.6
# episode 138 of 1000 complete,  explore val = 0.01, episode reward = 26.0, ave reward = 35.9
# episode 139 of 1000 complete,  explore val = 0.01, episode reward = 25.0, ave reward = 35.9
# episode 140 of 1000 complete,  explore val = 0.01, episode reward = 70.0, ave reward = 36.5
# episode 141 of 1000 complete,  explore val = 0.01, episode reward = 31.0, ave reward = 36.7
# episode 142 of 1000 complete,  explore val = 0.01, episode reward = 30.0, ave reward = 36.9
# episode 143 of 1000 complete,  explore val = 0.01, episode reward = 18.0, ave reward = 36.7
# episode 144 of 1000 complete,  explore val = 0.01, episode reward = 17.0, ave reward = 36.8
# episode 145 of 1000 complete,  explore val = 0.01, episode reward = 55.0, ave reward = 37.2
# episode 146 of 1000 complete,  explore val = 0.01, episode reward = 44.0, ave reward = 37.6
# episode 147 of 1000 complete,  explore val = 0.01, episode reward = 38.0, ave reward = 37.7
# episode 148 of 1000 complete,  explore val = 0.01, episode reward = 21.0, ave reward = 37.9
# episode 149 of 1000 complete,  explore val = 0.01, episode reward = 25.0, ave reward = 37.9
# episode 150 of 1000 complete,  explore val = 0.01, episode reward = 44.0, ave reward = 38.3
# episode 151 of 1000 complete,  explore val = 0.01, episode reward = 145.0, ave reward = 39.6
# episode 152 of 1000 complete,  explore val = 0.01, episode reward = 37.0, ave reward = 39.8
# episode 153 of 1000 complete,  explore val = 0.01, episode reward = 41.0, ave reward = 39.8
# episode 154 of 1000 complete,  explore val = 0.01, episode reward = 34.0, ave reward = 40.1
# episode 155 of 1000 complete,  explore val = 0.01, episode reward = 29.0, ave reward = 40.0
# episode 156 of 1000 complete,  explore val = 0.01, episode reward = 33.0, ave reward = 40.1
# episode 157 of 1000 complete,  explore val = 0.01, episode reward = 187.0, ave reward = 41.8
# episode 158 of 1000 complete,  explore val = 0.01, episode reward = 43.0, ave reward = 42.1
# episode 159 of 1000 complete,  explore val = 0.01, episode reward = 20.0, ave reward = 42.1
# episode 160 of 1000 complete,  explore val = 0.01, episode reward = 51.0, ave reward = 42.4
# episode 161 of 1000 complete,  explore val = 0.01, episode reward = 30.0, ave reward = 42.6
# episode 162 of 1000 complete,  explore val = 0.01, episode reward = 23.0, ave reward = 42.6
# episode 163 of 1000 complete,  explore val = 0.01, episode reward = 57.0, ave reward = 42.8
# episode 164 of 1000 complete,  explore val = 0.01, episode reward = 36.0, ave reward = 43.1
# episode 165 of 1000 complete,  explore val = 0.01, episode reward = 59.0, ave reward = 43.5
# episode 166 of 1000 complete,  explore val = 0.01, episode reward = 30.0, ave reward = 43.7
# episode 167 of 1000 complete,  explore val = 0.01, episode reward = 32.0, ave reward = 43.9
# episode 168 of 1000 complete,  explore val = 0.01, episode reward = 39.0, ave reward = 44.0
# episode 169 of 1000 complete,  explore val = 0.01, episode reward = 77.0, ave reward = 44.7
# episode 170 of 1000 complete,  explore val = 0.01, episode reward = 69.0, ave reward = 45.3
# episode 171 of 1000 complete,  explore val = 0.01, episode reward = 45.0, ave reward = 45.5
# episode 172 of 1000 complete,  explore val = 0.01, episode reward = 60.0, ave reward = 45.9
# episode 173 of 1000 complete,  explore val = 0.01, episode reward = 43.0, ave reward = 46.2
# episode 174 of 1000 complete,  explore val = 0.01, episode reward = 34.0, ave reward = 46.3
# episode 175 of 1000 complete,  explore val = 0.01, episode reward = 144.0, ave reward = 47.2
# episode 176 of 1000 complete,  explore val = 0.01, episode reward = 313.0, ave reward = 50.0
# episode 177 of 1000 complete,  explore val = 0.01, episode reward = 63.0, ave reward = 50.6
# episode 178 of 1000 complete,  explore val = 0.01, episode reward = 55.0, ave reward = 50.8
# episode 179 of 1000 complete,  explore val = 0.01, episode reward = 82.0, ave reward = 51.5
# episode 180 of 1000 complete,  explore val = 0.01, episode reward = 31.0, ave reward = 51.7
# episode 181 of 1000 complete,  explore val = 0.01, episode reward = 36.0, ave reward = 51.7
# episode 182 of 1000 complete,  explore val = 0.01, episode reward = 45.0, ave reward = 51.6
# episode 183 of 1000 complete,  explore val = 0.01, episode reward = 75.0, ave reward = 51.9
# episode 184 of 1000 complete,  explore val = 0.01, episode reward = 128.0, ave reward = 53.0
# episode 185 of 1000 complete,  explore val = 0.01, episode reward = 35.0, ave reward = 52.9
# episode 186 of 1000 complete,  explore val = 0.01, episode reward = 34.0, ave reward = 53.0
# episode 187 of 1000 complete,  explore val = 0.01, episode reward = 374.0, ave reward = 56.5
# episode 188 of 1000 complete,  explore val = 0.01, episode reward = 90.0, ave reward = 56.9
# episode 189 of 1000 complete,  explore val = 0.01, episode reward = 75.0, ave reward = 57.5
# episode 190 of 1000 complete,  explore val = 0.01, episode reward = 62.0, ave reward = 57.8
# episode 191 of 1000 complete,  explore val = 0.01, episode reward = 80.0, ave reward = 58.4
# episode 192 of 1000 complete,  explore val = 0.01, episode reward = 36.0, ave reward = 58.5
# episode 193 of 1000 complete,  explore val = 0.01, episode reward = 66.0, ave reward = 58.9
# episode 194 of 1000 complete,  explore val = 0.01, episode reward = 37.0, ave reward = 58.8
# episode 195 of 1000 complete,  explore val = 0.01, episode reward = 96.0, ave reward = 58.7
# episode 196 of 1000 complete,  explore val = 0.01, episode reward = 41.0, ave reward = 58.1
# episode 197 of 1000 complete,  explore val = 0.01, episode reward = 51.0, ave reward = 58.3
# episode 198 of 1000 complete,  explore val = 0.01, episode reward = 48.0, ave reward = 58.6
# episode 199 of 1000 complete,  explore val = 0.01, episode reward = 57.0, ave reward = 58.9
# episode 200 of 1000 complete,  explore val = 0.01, episode reward = 86.0, ave reward = 59.6
# episode 201 of 1000 complete,  explore val = 0.01, episode reward = 42.0, ave reward = 59.3
# episode 202 of 1000 complete,  explore val = 0.01, episode reward = 133.0, ave reward = 60.4
# episode 203 of 1000 complete,  explore val = 0.01, episode reward = 45.0, ave reward = 60.3
# episode 204 of 1000 complete,  explore val = 0.01, episode reward = 66.0, ave reward = 60.7
# episode 205 of 1000 complete,  explore val = 0.01, episode reward = 37.0, ave reward = 60.8
# episode 206 of 1000 complete,  explore val = 0.01, episode reward = 57.0, ave reward = 61.2
# episode 207 of 1000 complete,  explore val = 0.01, episode reward = 72.0, ave reward = 61.4
# episode 208 of 1000 complete,  explore val = 0.01, episode reward = 67.0, ave reward = 61.0
# episode 209 of 1000 complete,  explore val = 0.01, episode reward = 48.0, ave reward = 60.8
# episode 210 of 1000 complete,  explore val = 0.01, episode reward = 33.0, ave reward = 60.2
# episode 211 of 1000 complete,  explore val = 0.01, episode reward = 34.0, ave reward = 60.3
# episode 212 of 1000 complete,  explore val = 0.01, episode reward = 62.0, ave reward = 60.8
# episode 213 of 1000 complete,  explore val = 0.01, episode reward = 38.0, ave reward = 61.0
# episode 214 of 1000 complete,  explore val = 0.01, episode reward = 43.0, ave reward = 60.8
# episode 215 of 1000 complete,  explore val = 0.01, episode reward = 271.0, ave reward = 63.4
# episode 216 of 1000 complete,  explore val = 0.01, episode reward = 51.0, ave reward = 59.4
# episode 217 of 1000 complete,  explore val = 0.01, episode reward = 79.0, ave reward = 59.9
# episode 218 of 1000 complete,  explore val = 0.01, episode reward = 58.0, ave reward = 60.1
# episode 219 of 1000 complete,  explore val = 0.01, episode reward = 27.0, ave reward = 59.9
# episode 220 of 1000 complete,  explore val = 0.01, episode reward = 61.0, ave reward = 60.2
# episode 221 of 1000 complete,  explore val = 0.01, episode reward = 53.0, ave reward = 60.3
# episode 222 of 1000 complete,  explore val = 0.01, episode reward = 78.0, ave reward = 60.8
# episode 223 of 1000 complete,  explore val = 0.01, episode reward = 82.0, ave reward = 61.4
# episode 224 of 1000 complete,  explore val = 0.01, episode reward = 45.0, ave reward = 61.2
# episode 225 of 1000 complete,  explore val = 0.01, episode reward = 46.0, ave reward = 61.4
# episode 226 of 1000 complete,  explore val = 0.01, episode reward = 52.0, ave reward = 61.6
# episode 227 of 1000 complete,  explore val = 0.01, episode reward = 90.0, ave reward = 62.2
# episode 228 of 1000 complete,  explore val = 0.01, episode reward = 69.0, ave reward = 62.7
# episode 229 of 1000 complete,  explore val = 0.01, episode reward = 43.0, ave reward = 62.9
# episode 230 of 1000 complete,  explore val = 0.01, episode reward = 104.0, ave reward = 63.3
# episode 231 of 1000 complete,  explore val = 0.01, episode reward = 97.0, ave reward = 63.4
# episode 232 of 1000 complete,  explore val = 0.01, episode reward = 61.0, ave reward = 63.7
# episode 233 of 1000 complete,  explore val = 0.01, episode reward = 500.0, ave reward = 68.3
# episode 234 of 1000 complete,  explore val = 0.01, episode reward = 52.0, ave reward = 68.6
# episode 235 of 1000 complete,  explore val = 0.01, episode reward = 57.0, ave reward = 68.4
# episode 236 of 1000 complete,  explore val = 0.01, episode reward = 92.0, ave reward = 68.3
# episode 237 of 1000 complete,  explore val = 0.01, episode reward = 114.0, ave reward = 69.0
# episode 238 of 1000 complete,  explore val = 0.01, episode reward = 81.0, ave reward = 69.5
# episode 239 of 1000 complete,  explore val = 0.01, episode reward = 31.0, ave reward = 69.6
# episode 240 of 1000 complete,  explore val = 0.01, episode reward = 51.0, ave reward = 69.4
# episode 241 of 1000 complete,  explore val = 0.01, episode reward = 64.0, ave reward = 69.7
# episode 242 of 1000 complete,  explore val = 0.01, episode reward = 123.0, ave reward = 70.6
# episode 243 of 1000 complete,  explore val = 0.01, episode reward = 82.0, ave reward = 71.3
# episode 244 of 1000 complete,  explore val = 0.01, episode reward = 257.0, ave reward = 73.7
# episode 245 of 1000 complete,  explore val = 0.01, episode reward = 94.0, ave reward = 74.1
# episode 246 of 1000 complete,  explore val = 0.01, episode reward = 60.0, ave reward = 74.2
# episode 247 of 1000 complete,  explore val = 0.01, episode reward = 193.0, ave reward = 75.8
# episode 248 of 1000 complete,  explore val = 0.01, episode reward = 45.0, ave reward = 76.0
# episode 249 of 1000 complete,  explore val = 0.01, episode reward = 83.0, ave reward = 76.6
# episode 250 of 1000 complete,  explore val = 0.01, episode reward = 86.0, ave reward = 77.0
# episode 251 of 1000 complete,  explore val = 0.01, episode reward = 75.0, ave reward = 76.3
# episode 252 of 1000 complete,  explore val = 0.01, episode reward = 162.0, ave reward = 77.6
# episode 253 of 1000 complete,  explore val = 0.01, episode reward = 51.0, ave reward = 77.7
# episode 254 of 1000 complete,  explore val = 0.01, episode reward = 45.0, ave reward = 77.8
# episode 255 of 1000 complete,  explore val = 0.01, episode reward = 50.0, ave reward = 78.0
# episode 256 of 1000 complete,  explore val = 0.01, episode reward = 108.0, ave reward = 78.8
# episode 257 of 1000 complete,  explore val = 0.01, episode reward = 132.0, ave reward = 78.2
# episode 258 of 1000 complete,  explore val = 0.01, episode reward = 107.0, ave reward = 78.8
# episode 259 of 1000 complete,  explore val = 0.01, episode reward = 68.0, ave reward = 79.3
# episode 260 of 1000 complete,  explore val = 0.01, episode reward = 187.0, ave reward = 80.7
# episode 261 of 1000 complete,  explore val = 0.01, episode reward = 228.0, ave reward = 82.7
# episode 262 of 1000 complete,  explore val = 0.01, episode reward = 101.0, ave reward = 83.4
# episode 263 of 1000 complete,  explore val = 0.01, episode reward = 291.0, ave reward = 85.8
# episode 264 of 1000 complete,  explore val = 0.01, episode reward = 416.0, ave reward = 89.6
# episode 265 of 1000 complete,  explore val = 0.01, episode reward = 154.0, ave reward = 90.5
# episode 266 of 1000 complete,  explore val = 0.01, episode reward = 301.0, ave reward = 93.2
# episode 267 of 1000 complete,  explore val = 0.01, episode reward = 109.0, ave reward = 94.0
# episode 268 of 1000 complete,  explore val = 0.01, episode reward = 86.0, ave reward = 94.5
# episode 269 of 1000 complete,  explore val = 0.01, episode reward = 76.0, ave reward = 94.5
# episode 270 of 1000 complete,  explore val = 0.01, episode reward = 130.0, ave reward = 95.1
# episode 271 of 1000 complete,  explore val = 0.01, episode reward = 55.0, ave reward = 95.2
# episode 272 of 1000 complete,  explore val = 0.01, episode reward = 65.0, ave reward = 95.2
# episode 273 of 1000 complete,  explore val = 0.01, episode reward = 59.0, ave reward = 95.4
# episode 274 of 1000 complete,  explore val = 0.01, episode reward = 53.0, ave reward = 95.6
# episode 275 of 1000 complete,  explore val = 0.01, episode reward = 60.0, ave reward = 94.7
# episode 276 of 1000 complete,  explore val = 0.01, episode reward = 116.0, ave reward = 92.8
# episode 277 of 1000 complete,  explore val = 0.01, episode reward = 81.0, ave reward = 93.0
# episode 278 of 1000 complete,  explore val = 0.01, episode reward = 84.0, ave reward = 93.2
# episode 279 of 1000 complete,  explore val = 0.01, episode reward = 79.0, ave reward = 93.2
# episode 280 of 1000 complete,  explore val = 0.01, episode reward = 80.0, ave reward = 93.7
# episode 281 of 1000 complete,  explore val = 0.01, episode reward = 119.0, ave reward = 94.5
# episode 282 of 1000 complete,  explore val = 0.01, episode reward = 92.0, ave reward = 95.0
# episode 283 of 1000 complete,  explore val = 0.01, episode reward = 69.0, ave reward = 94.9
# episode 284 of 1000 complete,  explore val = 0.01, episode reward = 61.0, ave reward = 94.3
# episode 285 of 1000 complete,  explore val = 0.01, episode reward = 50.0, ave reward = 94.4
# episode 286 of 1000 complete,  explore val = 0.01, episode reward = 58.0, ave reward = 94.7
# episode 287 of 1000 complete,  explore val = 0.01, episode reward = 71.0, ave reward = 91.6
# episode 288 of 1000 complete,  explore val = 0.01, episode reward = 77.0, ave reward = 91.5
# episode 289 of 1000 complete,  explore val = 0.01, episode reward = 85.0, ave reward = 91.6
# episode 290 of 1000 complete,  explore val = 0.01, episode reward = 63.0, ave reward = 91.6
# episode 291 of 1000 complete,  explore val = 0.01, episode reward = 50.0, ave reward = 91.3
# episode 292 of 1000 complete,  explore val = 0.01, episode reward = 49.0, ave reward = 91.4
# episode 293 of 1000 complete,  explore val = 0.01, episode reward = 53.0, ave reward = 91.3
# episode 294 of 1000 complete,  explore val = 0.01, episode reward = 33.0, ave reward = 91.3
# episode 295 of 1000 complete,  explore val = 0.01, episode reward = 41.0, ave reward = 90.7
# episode 296 of 1000 complete,  explore val = 0.01, episode reward = 94.0, ave reward = 91.2
# episode 297 of 1000 complete,  explore val = 0.01, episode reward = 80.0, ave reward = 91.5
# episode 298 of 1000 complete,  explore val = 0.01, episode reward = 434.0, ave reward = 95.4
# episode 299 of 1000 complete,  explore val = 0.01, episode reward = 112.0, ave reward = 96.0
# episode 300 of 1000 complete,  explore val = 0.01, episode reward = 125.0, ave reward = 96.3
# episode 301 of 1000 complete,  explore val = 0.01, episode reward = 105.0, ave reward = 97.0
# episode 302 of 1000 complete,  explore val = 0.01, episode reward = 77.0, ave reward = 96.4
# episode 303 of 1000 complete,  explore val = 0.01, episode reward = 48.0, ave reward = 96.4
# episode 304 of 1000 complete,  explore val = 0.01, episode reward = 96.0, ave reward = 96.7
# episode 305 of 1000 complete,  explore val = 0.01, episode reward = 191.0, ave reward = 98.3
# episode 306 of 1000 complete,  explore val = 0.01, episode reward = 79.0, ave reward = 98.5
# episode 307 of 1000 complete,  explore val = 0.01, episode reward = 358.0, ave reward = 101.4
# episode 308 of 1000 complete,  explore val = 0.01, episode reward = 96.0, ave reward = 101.6
# episode 309 of 1000 complete,  explore val = 0.01, episode reward = 81.0, ave reward = 102.0
# episode 310 of 1000 complete,  explore val = 0.01, episode reward = 256.0, ave reward = 104.2
# episode 311 of 1000 complete,  explore val = 0.01, episode reward = 74.0, ave reward = 104.6
# episode 312 of 1000 complete,  explore val = 0.01, episode reward = 56.0, ave reward = 104.6
# episode 313 of 1000 complete,  explore val = 0.01, episode reward = 437.0, ave reward = 108.5
# episode 314 of 1000 complete,  explore val = 0.01, episode reward = 397.0, ave reward = 112.1
# episode 315 of 1000 complete,  explore val = 0.01, episode reward = 302.0, ave reward = 112.4
# episode 316 of 1000 complete,  explore val = 0.01, episode reward = 75.0, ave reward = 112.6
# episode 317 of 1000 complete,  explore val = 0.01, episode reward = 109.0, ave reward = 112.9
# episode 318 of 1000 complete,  explore val = 0.01, episode reward = 63.0, ave reward = 113.0
# episode 319 of 1000 complete,  explore val = 0.01, episode reward = 52.0, ave reward = 113.2
# episode 320 of 1000 complete,  explore val = 0.01, episode reward = 51.0, ave reward = 113.1
# episode 321 of 1000 complete,  explore val = 0.01, episode reward = 123.0, ave reward = 113.8
# episode 322 of 1000 complete,  explore val = 0.01, episode reward = 77.0, ave reward = 113.8
# episode 323 of 1000 complete,  explore val = 0.01, episode reward = 61.0, ave reward = 113.6
# episode 324 of 1000 complete,  explore val = 0.01, episode reward = 54.0, ave reward = 113.7
# episode 325 of 1000 complete,  explore val = 0.01, episode reward = 52.0, ave reward = 113.8
# episode 326 of 1000 complete,  explore val = 0.01, episode reward = 57.0, ave reward = 113.8
# episode 327 of 1000 complete,  explore val = 0.01, episode reward = 51.0, ave reward = 113.4
# episode 328 of 1000 complete,  explore val = 0.01, episode reward = 38.0, ave reward = 113.1
# episode 329 of 1000 complete,  explore val = 0.01, episode reward = 31.0, ave reward = 113.0
# episode 330 of 1000 complete,  explore val = 0.01, episode reward = 26.0, ave reward = 112.2
# episode 331 of 1000 complete,  explore val = 0.01, episode reward = 79.0, ave reward = 112.0
# episode 332 of 1000 complete,  explore val = 0.01, episode reward = 33.0, ave reward = 111.8
# episode 333 of 1000 complete,  explore val = 0.01, episode reward = 190.0, ave reward = 108.6
# episode 334 of 1000 complete,  explore val = 0.01, episode reward = 77.0, ave reward = 108.9
# episode 335 of 1000 complete,  explore val = 0.01, episode reward = 27.0, ave reward = 108.6
# episode 336 of 1000 complete,  explore val = 0.01, episode reward = 219.0, ave reward = 109.9
# episode 337 of 1000 complete,  explore val = 0.01, episode reward = 80.0, ave reward = 109.5
# episode 338 of 1000 complete,  explore val = 0.01, episode reward = 158.0, ave reward = 110.3
# episode 339 of 1000 complete,  explore val = 0.01, episode reward = 33.0, ave reward = 110.3
# episode 340 of 1000 complete,  explore val = 0.01, episode reward = 31.0, ave reward = 110.1
# episode 341 of 1000 complete,  explore val = 0.01, episode reward = 30.0, ave reward = 109.8
# episode 342 of 1000 complete,  explore val = 0.01, episode reward = 112.0, ave reward = 109.7
# episode 343 of 1000 complete,  explore val = 0.01, episode reward = 54.0, ave reward = 109.4
# episode 344 of 1000 complete,  explore val = 0.01, episode reward = 33.0, ave reward = 107.2
# episode 345 of 1000 complete,  explore val = 0.01, episode reward = 46.0, ave reward = 106.7
# episode 346 of 1000 complete,  explore val = 0.01, episode reward = 55.0, ave reward = 106.6
# episode 347 of 1000 complete,  explore val = 0.01, episode reward = 254.0, ave reward = 107.2
# episode 348 of 1000 complete,  explore val = 0.01, episode reward = 45.0, ave reward = 107.2
# episode 349 of 1000 complete,  explore val = 0.01, episode reward = 46.0, ave reward = 106.9
# episode 350 of 1000 complete,  explore val = 0.01, episode reward = 76.0, ave reward = 106.8
# episode 351 of 1000 complete,  explore val = 0.01, episode reward = 207.0, ave reward = 108.1
# episode 352 of 1000 complete,  explore val = 0.01, episode reward = 41.0, ave reward = 106.9
# episode 353 of 1000 complete,  explore val = 0.01, episode reward = 43.0, ave reward = 106.8
# episode 354 of 1000 complete,  explore val = 0.01, episode reward = 48.0, ave reward = 106.8
# episode 355 of 1000 complete,  explore val = 0.01, episode reward = 48.0, ave reward = 106.8
# episode 356 of 1000 complete,  explore val = 0.01, episode reward = 59.0, ave reward = 106.3
# episode 357 of 1000 complete,  explore val = 0.01, episode reward = 40.0, ave reward = 105.4
# episode 358 of 1000 complete,  explore val = 0.01, episode reward = 54.0, ave reward = 104.9
# episode 359 of 1000 complete,  explore val = 0.01, episode reward = 43.0, ave reward = 104.6
# episode 360 of 1000 complete,  explore val = 0.01, episode reward = 33.0, ave reward = 103.1
# episode 361 of 1000 complete,  explore val = 0.01, episode reward = 32.0, ave reward = 101.1
# episode 362 of 1000 complete,  explore val = 0.01, episode reward = 26.0, ave reward = 100.4
# episode 363 of 1000 complete,  explore val = 0.01, episode reward = 92.0, ave reward = 98.4
# episode 364 of 1000 complete,  explore val = 0.01, episode reward = 76.0, ave reward = 95.0
# episode 365 of 1000 complete,  explore val = 0.01, episode reward = 140.0, ave reward = 94.8
# episode 366 of 1000 complete,  explore val = 0.01, episode reward = 59.0, ave reward = 92.4
# episode 367 of 1000 complete,  explore val = 0.01, episode reward = 233.0, ave reward = 93.6
# episode 368 of 1000 complete,  explore val = 0.01, episode reward = 63.0, ave reward = 93.4
# episode 369 of 1000 complete,  explore val = 0.01, episode reward = 77.0, ave reward = 93.4
# episode 370 of 1000 complete,  explore val = 0.01, episode reward = 54.0, ave reward = 92.7
# episode 371 of 1000 complete,  explore val = 0.01, episode reward = 103.0, ave reward = 93.2
# episode 372 of 1000 complete,  explore val = 0.01, episode reward = 92.0, ave reward = 93.4
# episode 373 of 1000 complete,  explore val = 0.01, episode reward = 80.0, ave reward = 93.6
# episode 374 of 1000 complete,  explore val = 0.01, episode reward = 346.0, ave reward = 96.6
# episode 375 of 1000 complete,  explore val = 0.01, episode reward = 132.0, ave reward = 97.3
# episode 376 of 1000 complete,  explore val = 0.01, episode reward = 85.0, ave reward = 97.0
# episode 377 of 1000 complete,  explore val = 0.01, episode reward = 92.0, ave reward = 97.1
# episode 378 of 1000 complete,  explore val = 0.01, episode reward = 81.0, ave reward = 97.0
# episode 379 of 1000 complete,  explore val = 0.01, episode reward = 148.0, ave reward = 97.7
# episode 380 of 1000 complete,  explore val = 0.01, episode reward = 68.0, ave reward = 97.6
# episode 381 of 1000 complete,  explore val = 0.01, episode reward = 83.0, ave reward = 97.3
# episode 382 of 1000 complete,  explore val = 0.01, episode reward = 82.0, ave reward = 97.2
# episode 383 of 1000 complete,  explore val = 0.01, episode reward = 63.0, ave reward = 97.1
# episode 384 of 1000 complete,  explore val = 0.01, episode reward = 190.0, ave reward = 98.4
# episode 385 of 1000 complete,  explore val = 0.01, episode reward = 56.0, ave reward = 98.4
# episode 386 of 1000 complete,  explore val = 0.01, episode reward = 63.0, ave reward = 98.5
# episode 387 of 1000 complete,  explore val = 0.01, episode reward = 78.0, ave reward = 98.6
# episode 388 of 1000 complete,  explore val = 0.01, episode reward = 49.0, ave reward = 98.3
# episode 389 of 1000 complete,  explore val = 0.01, episode reward = 75.0, ave reward = 98.2
# episode 390 of 1000 complete,  explore val = 0.01, episode reward = 87.0, ave reward = 98.4
# episode 391 of 1000 complete,  explore val = 0.01, episode reward = 59.0, ave reward = 98.5
# episode 392 of 1000 complete,  explore val = 0.01, episode reward = 71.0, ave reward = 98.7
# episode 393 of 1000 complete,  explore val = 0.01, episode reward = 67.0, ave reward = 98.9
# episode 394 of 1000 complete,  explore val = 0.01, episode reward = 62.0, ave reward = 99.2
# episode 395 of 1000 complete,  explore val = 0.01, episode reward = 75.0, ave reward = 99.5
# episode 396 of 1000 complete,  explore val = 0.01, episode reward = 71.0, ave reward = 99.3
# episode 397 of 1000 complete,  explore val = 0.01, episode reward = 109.0, ave reward = 99.6
# episode 398 of 1000 complete,  explore val = 0.01, episode reward = 42.0, ave reward = 95.6
# episode 399 of 1000 complete,  explore val = 0.01, episode reward = 56.0, ave reward = 95.1
# episode 400 of 1000 complete,  explore val = 0.01, episode reward = 80.0, ave reward = 94.6
# episode 401 of 1000 complete,  explore val = 0.01, episode reward = 199.0, ave reward = 95.6
# episode 402 of 1000 complete,  explore val = 0.01, episode reward = 83.0, ave reward = 95.6
# episode 403 of 1000 complete,  explore val = 0.01, episode reward = 75.0, ave reward = 95.9
# episode 404 of 1000 complete,  explore val = 0.01, episode reward = 76.0, ave reward = 95.7
# episode 405 of 1000 complete,  explore val = 0.01, episode reward = 425.0, ave reward = 98.0
# episode 406 of 1000 complete,  explore val = 0.01, episode reward = 82.0, ave reward = 98.1
# episode 407 of 1000 complete,  explore val = 0.01, episode reward = 500.0, ave reward = 99.5
# episode 408 of 1000 complete,  explore val = 0.01, episode reward = 43.0, ave reward = 99.0
# episode 409 of 1000 complete,  explore val = 0.01, episode reward = 240.0, ave reward = 100.6
# episode 410 of 1000 complete,  explore val = 0.01, episode reward = 41.0, ave reward = 98.4
# episode 411 of 1000 complete,  explore val = 0.01, episode reward = 72.0, ave reward = 98.4
# episode 412 of 1000 complete,  explore val = 0.01, episode reward = 98.0, ave reward = 98.8
# episode 413 of 1000 complete,  explore val = 0.01, episode reward = 77.0, ave reward = 95.2
# episode 414 of 1000 complete,  explore val = 0.01, episode reward = 95.0, ave reward = 92.2
# episode 415 of 1000 complete,  explore val = 0.01, episode reward = 279.0, ave reward = 92.0
# episode 416 of 1000 complete,  explore val = 0.01, episode reward = 428.0, ave reward = 95.5
# episode 417 of 1000 complete,  explore val = 0.01, episode reward = 500.0, ave reward = 99.4
# episode 418 of 1000 complete,  explore val = 0.01, episode reward = 81.0, ave reward = 99.6
# episode 419 of 1000 complete,  explore val = 0.01, episode reward = 191.0, ave reward = 101.0
# episode 420 of 1000 complete,  explore val = 0.01, episode reward = 312.0, ave reward = 103.6
# episode 421 of 1000 complete,  explore val = 0.01, episode reward = 500.0, ave reward = 107.4
# episode 422 of 1000 complete,  explore val = 0.01, episode reward = 109.0, ave reward = 107.7
# episode 423 of 1000 complete,  explore val = 0.01, episode reward = 57.0, ave reward = 107.6
# episode 424 of 1000 complete,  explore val = 0.01, episode reward = 45.0, ave reward = 107.5
# episode 425 of 1000 complete,  explore val = 0.01, episode reward = 55.0, ave reward = 107.6
# episode 426 of 1000 complete,  explore val = 0.01, episode reward = 93.0, ave reward = 107.9
# episode 427 of 1000 complete,  explore val = 0.01, episode reward = 65.0, ave reward = 108.1
# episode 428 of 1000 complete,  explore val = 0.01, episode reward = 80.0, ave reward = 108.5
# episode 429 of 1000 complete,  explore val = 0.01, episode reward = 350.0, ave reward = 111.7
# episode 430 of 1000 complete,  explore val = 0.01, episode reward = 500.0, ave reward = 116.4
# episode 431 of 1000 complete,  explore val = 0.01, episode reward = 342.0, ave reward = 119.0
# episode 432 of 1000 complete,  explore val = 0.01, episode reward = 135.0, ave reward = 120.1
# episode 433 of 1000 complete,  explore val = 0.01, episode reward = 72.0, ave reward = 118.9
# episode 434 of 1000 complete,  explore val = 0.01, episode reward = 399.0, ave reward = 122.1
# episode 435 of 1000 complete,  explore val = 0.01, episode reward = 82.0, ave reward = 122.7
# episode 436 of 1000 complete,  explore val = 0.01, episode reward = 230.0, ave reward = 122.8
# episode 437 of 1000 complete,  explore val = 0.01, episode reward = 174.0, ave reward = 123.7
# episode 438 of 1000 complete,  explore val = 0.01, episode reward = 264.0, ave reward = 124.8
# episode 439 of 1000 complete,  explore val = 0.01, episode reward = 290.0, ave reward = 127.3
# episode 440 of 1000 complete,  explore val = 0.01, episode reward = 108.0, ave reward = 128.1
# episode 441 of 1000 complete,  explore val = 0.01, episode reward = 443.0, ave reward = 132.2
# episode 442 of 1000 complete,  explore val = 0.01, episode reward = 267.0, ave reward = 133.8
# episode 443 of 1000 complete,  explore val = 0.01, episode reward = 310.0, ave reward = 136.4
# episode 444 of 1000 complete,  explore val = 0.01, episode reward = 127.0, ave reward = 137.3
# episode 445 of 1000 complete,  explore val = 0.01, episode reward = 230.0, ave reward = 139.1
# episode 446 of 1000 complete,  explore val = 0.01, episode reward = 289.0, ave reward = 141.5
# episode 447 of 1000 complete,  explore val = 0.01, episode reward = 174.0, ave reward = 140.7
# episode 448 of 1000 complete,  explore val = 0.01, episode reward = 201.0, ave reward = 142.2
# episode 449 of 1000 complete,  explore val = 0.01, episode reward = 236.0, ave reward = 144.1
# episode 450 of 1000 complete,  explore val = 0.01, episode reward = 232.0, ave reward = 145.7
# episode 451 of 1000 complete,  explore val = 0.01, episode reward = 130.0, ave reward = 144.9
# episode 452 of 1000 complete,  explore val = 0.01, episode reward = 237.0, ave reward = 146.9
# episode 453 of 1000 complete,  explore val = 0.01, episode reward = 290.0, ave reward = 149.4
# episode 454 of 1000 complete,  explore val = 0.01, episode reward = 218.0, ave reward = 151.0
# episode 455 of 1000 complete,  explore val = 0.01, episode reward = 177.0, ave reward = 152.3
# episode 456 of 1000 complete,  explore val = 0.01, episode reward = 240.0, ave reward = 154.2
# episode 457 of 1000 complete,  explore val = 0.01, episode reward = 171.0, ave reward = 155.5
# episode 458 of 1000 complete,  explore val = 0.01, episode reward = 177.0, ave reward = 156.7
# episode 459 of 1000 complete,  explore val = 0.01, episode reward = 238.0, ave reward = 158.6
# episode 460 of 1000 complete,  explore val = 0.01, episode reward = 429.0, ave reward = 162.6
# episode 461 of 1000 complete,  explore val = 0.01, episode reward = 325.0, ave reward = 165.5
# episode 462 of 1000 complete,  explore val = 0.01, episode reward = 190.0, ave reward = 167.2
# episode 463 of 1000 complete,  explore val = 0.01, episode reward = 270.0, ave reward = 169.0
# episode 464 of 1000 complete,  explore val = 0.01, episode reward = 259.0, ave reward = 170.8
# episode 465 of 1000 complete,  explore val = 0.01, episode reward = 335.0, ave reward = 172.7
# episode 466 of 1000 complete,  explore val = 0.01, episode reward = 264.0, ave reward = 174.8
# episode 467 of 1000 complete,  explore val = 0.01, episode reward = 300.0, ave reward = 175.4
# episode 468 of 1000 complete,  explore val = 0.01, episode reward = 330.0, ave reward = 178.1
# episode 469 of 1000 complete,  explore val = 0.01, episode reward = 328.0, ave reward = 180.6
# episode 470 of 1000 complete,  explore val = 0.01, episode reward = 294.0, ave reward = 183.0
# episode 471 of 1000 complete,  explore val = 0.01, episode reward = 302.0, ave reward = 185.0
# episode 472 of 1000 complete,  explore val = 0.01, episode reward = 500.0, ave reward = 189.1
# episode 473 of 1000 complete,  explore val = 0.01, episode reward = 329.0, ave reward = 191.6
# episode 474 of 1000 complete,  explore val = 0.01, episode reward = 319.0, ave reward = 191.3
# episode 475 of 1000 complete,  explore val = 0.01, episode reward = 372.0, ave reward = 193.7
# episode 476 of 1000 complete,  explore val = 0.01, episode reward = 332.0, ave reward = 196.2
# episode 477 of 1000 complete,  explore val = 0.01, episode reward = 297.0, ave reward = 198.2
# episode 478 of 1000 complete,  explore val = 0.01, episode reward = 292.0, ave reward = 200.4
# q-learning algorithm complete

# %% [markdown]
# # Plot total episode reward history

# %%
reward_logname = 'reward_logs/' + savename + '.txt'
plot_reward_history(reward_logname,window_length = exit_window)
